# %%
'''
prompt:
Gere codigo python que se conecta na API do Gemini e submete um prompt.
'''
# Out:
# '\nprompt:\nGere codigo python que se conecta na API do Gemini e submete um prompt.\n'

# %%
pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.8.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-api-python-client in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.174.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.40.3)
# Requirement already satisfied: protobuf in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.6.1)
# Requirement already satisfied: tqdm in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (4.66.1)
# Requirement already satisfied: typing-extensions in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core->google-generativeai) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic->google-generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic->google-generativeai) (2.16.2)
# Requirement already satisfied: colorama in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.73.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\pedro\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import google.generativeai as genai

# Substitua pela sua chave de API
API_KEY = "AIzaSyCXAuCP5LWl4Bk5i-6Ha-EX6NxnU8QxDNYA"

model_name = "gemini-2.5-flash"

# Configura a API
genai.configure(api_key=API_KEY)

# Cria o modelo
model = genai.GenerativeModel(model_name)

# Submete o prompt
prompt = "Explique a teoria da relatividade em termos simples"
response = model.generate_content(prompt)

# Exibe a resposta
print(response.text)
# Out:
# A Teoria da Relatividade, desenvolvida por Albert Einstein, é na verdade composta por duas partes: a Relatividade Especial (1905) e a Relatividade Geral (1915). Em termos super simples, ela nos diz que **espaço e tempo não são fixos e absolutos, mas sim flexíveis e interconectados, e podem ser afetados pela velocidade e pela gravidade.**
#
# Vamos desmembrar:
#
# ---
#
# ### **1. A Relatividade Especial (Velocidade)**
#
# **Ideia principal:** As leis da física são as mesmas para todos que estão se movendo em velocidade constante, e a velocidade da luz no vácuo é sempre a mesma para qualquer observador, não importa quão rápido ele esteja se movendo.
#
# **Pense assim:**
#
# *   **Tudo é relativo (exceto a luz):** Imagine que você está em um trem se movendo suavemente. Se você jogar uma bola para cima, ela cai na sua mão, como se o trem estivesse parado. As leis da física (a gravidade puxando a bola) funcionam da mesma forma para você no trem e para alguém parado na estação. Não há um "ponto de referência" absoluto no universo.
# *   **A velocidade da luz é a "lei":** Mas Einstein descobriu algo incrível: a velocidade da luz é uma exceção. Ela é sempre a mesma (cerca de 300.000 km por segundo) para *qualquer um* que a meça, esteja essa pessoa parada ou voando em um foguete a quase a velocidade da luz.
# *   **As "consequências estranhas":** Para que a velocidade da luz seja sempre constante para todos, algo tem que ceder: o espaço e o tempo.
#     *   **Dilatação do Tempo:** Se você se move muito rápido, seu tempo passa mais devagar em comparação com alguém que está parado. (Se um astronauta fizesse uma viagem de ida e volta a uma velocidade próxima à da luz, ele envelheceria menos do que seus amigos na Terra).
#     *   **Contração do Comprimento:** Objetos em movimento muito rápido parecem encurtar na direção do movimento.
#     *   **Equivalência Massa-Energia (E=mc²):** Esta é a fórmula mais famosa! Ela diz que massa e energia são a mesma coisa, apenas em formas diferentes. Uma pequena quantidade de massa pode ser convertida em uma quantidade enorme de energia (como em bombas atômicas ou no Sol). Isso significa que, à medida que algo acelera, sua massa também aumenta, tornando mais difícil acelerar ainda mais. É por isso que nada com massa pode atingir a velocidade da luz – exigiria energia infinita.
#
# ---
#
# ### **2. A Relatividade Geral (Gravidade)**
#
# **Ideia principal:** A gravidade não é uma força misteriosa que "puxa" os objetos, mas sim uma **curvatura no tecido do espaço-tempo** causada pela presença de massa e energia.
#
# **Pense assim:**
#
# *   **O tecido do espaço-tempo:** Imagine o universo como uma cama elástica gigante. Se você colocar uma bola de boliche no meio (que representa um planeta ou estrela massiva), ela cria uma depressão.
# *   **Como a gravidade "funciona":** Quando você joga uma bolinha de gude perto da bola de boliche, a bolinha não é "puxada" pela bola de boliche; em vez disso, ela rola *pela depressão* que a bola de boliche criou na cama elástica. É assim que a Relatividade Geral explica a gravidade: planetas e estrelas deformam o espaço-tempo ao seu redor, e outros objetos (como asteroides ou até a luz) simplesmente seguem as curvas desse espaço-tempo deformado.
# *   **Aplicações:**
#     *   **Luz que se curva:** Se a luz segue as curvas do espaço-tempo, então a luz de estrelas distantes deve se curvar quando passa perto de objetos muito massivos, como o Sol. Isso foi observado e provado! (É a base para o conceito de "lentes gravitacionais").
#     *   **O tempo na gravidade:** A gravidade também afeta o tempo. Relógios correm mais devagar em locais onde a gravidade é mais forte (como na superfície da Terra) e um pouco mais rápido onde a gravidade é mais fraca (como em órbita). Isso é crucial para o funcionamento do GPS! Os satélites GPS precisam compensar essa diferença minúscula de tempo para que a sua localização seja precisa.
#     *   **Buracos Negros:** São o resultado extremo da gravidade curvando o espaço-tempo a tal ponto que nada, nem mesmo a luz, pode escapar.
#
# ---
#
# ### **Em resumo:**
#
# A Teoria da Relatividade de Einstein transformou nossa compreensão do universo, mostrando que:
#
# *   **Espaço e tempo não são separados e absolutos, mas sim um único "tecido" flexível chamado espaço-tempo.**
# *   **Sua percepção de espaço e tempo depende da sua velocidade e da gravidade ao seu redor.**
# *   **A velocidade da luz é o limite de velocidade cósmico e é constante para todos.**
# *   **A gravidade não é uma força, mas a maneira como a massa deforma o espaço-tempo, fazendo com que tudo se "curva" em sua direção.**
#
# É uma teoria radical, mas incrivelmente bem comprovada por experimentos e observações. Ela é a base de grande parte da nossa física moderna e da cosmologia.

# %%
import pandas as pd

# Caminho para o arquivo CSV
caminho_csv = "data/oab.csv"  # ou "oab.csv" se estiver na raiz do projeto

# Lê o CSV em um DataFrame
oab_questions_df = pd.read_csv(caminho_csv)

# Visualiza as primeiras linhas
oab_questions_df.head()
# Out:
#   pdf_filename prova             materia                             tema  \
# 0    oab-1.pdf    XV  ÉTICA PROFISSIONAL  INCOMPATIBILIDADE E IMPEDIMENTO
# 1    oab-1.pdf    XV  ÉTICA PROFISSIONAL             DIREITOS DO ADVOGADO
# 2    oab-1.pdf    XV  ÉTICA PROFISSIONAL           ATIVIDADE DE ADVOCACIA
# 3    oab-1.pdf    XV  ÉTICA PROFISSIONAL           SOCIEDADE DE ADVOGADOS
# 4    oab-1.pdf   XIV  ÉTICA PROFISSIONAL           ATIVIDADE DE ADVOCACIA
#
#    questao                                          enunciado  \
# 0        1  Abelardo é magistrado vinculado ao Tribunal de...
# 1        2  Fred, jovem advogado, é contratado para presta...
# 2        3  O advogado Caio atuava representando os intere...
# 3        4  Os advogados X de Souza, Y dos Santos e Z de A...
# 4        5  Matheus é estagiário vinculado ao escritório R...
#
#                                                    A  \
# 0  A incompatibilidade com a advocacia persiste m...
# 1  deve submeter-se à determinação da gerência ju...
# 2  Tício não pode ajuizar tal ação porque, como C...
# 3  É possível manter o nome do sócio falecido, de...
# 4  O advogado pode afastar-se do processo em que ...
#
#                                      justificativa_A  \
# 0  : Afirmação falsa. Após a aposentadoria do jui...
# 1  : Afirmação falsa. Todo advogado possui liberd...
# 2  : Afirmação falsa. Os honorários são devidos (...
# 3  : Alternativa correta. Nos termos do art. 16, ...
# 4  : Afirmação falsa. O advogado, ao renunciar o ...
#
#                                                    B  \
# 0  O afastamento temporário do cargo que gera a i...
# 1  deve apresentar seu parecer ao conjunto de adv...
# 2  Tício pode ajuizar tal ação, pois ingressou na...
# 3  É possível manter o nome do sócio falecido, in...
# 4  A renúncia deve ser notificada ao cliente pelo...
#
#                                      justificativa_B  \
# 0  : Afirmação falsa. A incompatibilidade persist...
# 1  : Afirmação falsa. Não há necessidade de delib...
# 2  : Afirmação falsa. O momento de ingresso do ad...
# 3  : Afirmação falsa. Para manter o nome do sócio...
# 4  : Alternativa correta. A renúncia deve ser com...
#
#                                                    C  \
# 0  A incompatibilidade permanece mesmo que ocorra...
# 1  pode recusar-se a propor a ação diante do pare...
# 2  Tício pode ajuizar tal ação, pois, embora não ...
# 3  É absolutamente vedada a manutenção do nome do...
# 4  A renúncia aos poderes conferidos no mandato d...
#
#                                      justificativa_C  \
# 0  : Alternativa correta. Conforme o art. 28, §1º...
# 1  : Alternativa correta. Fred não é obrigado a a...
# 2  : Afirmação falsa. O advogado substabelecido, ...
# 3  : Afirmação falsa. O EAOAB permite que se mant...
# 4  : Afrirmação falsa. A renúnca configura ato un...
#
#                                                    D  \
# 0  O afastamento do cargo incompatível permite a ...
# 1         pode opor-se e postular assessoria da OAB.
# 2  Tício não pode ajuizar tal ação porque o advog...
# 3  É possível manter, pelo prazo máximo de seis m...
# 4  A renúncia ao mandato, sem respeitar o prazo l...
#
#                                      justificativa_D correct
# 0  : Afirmação falsa. Não há qualquer previsão le...       C
# 1  : Afirmação falsa. Não há previsão legal para ...       C
# 2  : Alternativa correta. O advogado substabeleci...       D
# 3  : Afirmação falsa. O EAOAB não fixa qualquer p...       A
# 4  : Afirmação falsa para FGV. A renúncia ao mand...       B

# %%
# Caminho para o arquivo
caminho_prompt = "prompts/solve_question_prompt.txt"

# Lê o conteúdo do arquivo como string
with open(caminho_prompt, "r", encoding="utf-8") as arquivo:
    prompt_text = arquivo.read()

# Exibe parte do conteúdo
print(prompt_text[:500])  # Mostra os primeiros 500 caracteres
# Out:
# Resolva a questão o exame da ordem a OAB abaixo.
# Forneça a resposta no formato "resposta: [alternativa]", em que alternativa é A, B, C ou D.

# %%
'''
prompt:
Escreva uma função parse_answer(response) que procura pelo texto "resposta: [alternativa]" e retorna a a alternativa, que deve ser "A", "B", "C" ou "D". "Resposta" pode vir em maiúsculo ou minúsculo.

'''

import re

def parse_answer(response):
    """
    Extrai a alternativa da resposta a partir de um texto que contenha algo como 'Resposta: B' ou 'resposta: d'.
    Retorna 'A', 'B', 'C' ou 'D'. Se não encontrar, retorna None.
    """
    padrao = r"resposta:\s*([ABCD])"
    match = re.search(padrao, response, flags=re.IGNORECASE)
    if match:
        return match.group(1).upper()
    return None

# %%
import pandas as pd
import time
from tqdm import tqdm  

def run_exam(oab_questions_df, model_name, N):
    genai.configure(api_key=API_KEY)
    model = genai.GenerativeModel(model_name)

    amostra_df = oab_questions_df.sample(n=N, random_state=43).reset_index(drop=True)

    answers_df = pd.DataFrame(columns=[
        "prova", "questao", "enunciado",
        "A", "B", "C", "D",
        "resposta_completa", "alternativa"
    ])

    for index, row in tqdm(amostra_df.iterrows(), total=N, desc=f"Executando questões {model_name}"):
        #print("\n" + "=" * 40)
        #print(f"Questão {index}")
        #print("-" * 40)

        question_body = f'''
        {row['enunciado']}

        A) {row['A']}
        B) {row['B']}
        C) {row['C']}
        D) {row['D']}
        '''

        response = model.generate_content(prompt_text + "\n" + question_body)
        resposta_texto = response.text
        answer = parse_answer(resposta_texto)

        #print('answer:', answer)

        answers_df = pd.concat([
            answers_df,
            pd.DataFrame([{
                "pdf_filename": row['pdf_filename'],
                "materia": row['materia'],
                "prova": row['prova'],
                "questao": row['questao'],
                "enunciado": row['enunciado'],
                "A": row['A'],
                "B": row['B'],
                "C": row['C'],
                "D": row['D'],
                "resposta_completa": resposta_texto,
                "alternativa": answer,
                "correct": row['correct']
            }])
        ], ignore_index=True)

        time.sleep(15)

    answers_df.to_csv(f"data/{model_name}_answers.csv", index=False)

# %%
N = 30

#run_exam(oab_questions_df, "gemini-1.5-flash-8b", N)
run_exam(oab_questions_df, "gemini-1.5-flash", N)
#run_exam(oab_questions_df, "gemini-2.0-flash", N)
#run_exam(oab_questions_df, "gemini-2.5-flash", N)
# Out:
# Executando questões gemini-1.5-flash:   0%|          | 0/30 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[79], line 4
#       1 N = 30
#       3 #run_exam(oab_questions_df, "gemini-1.5-flash-8b", N)
# ----> 4 run_exam(oab_questions_df, "gemini-1.5-flash", N)
#       5 #run_exam(oab_questions_df, "gemini-2.0-flash", N)
#       6 #run_exam(oab_questions_df, "gemini-2.5-flash", N)
#
# Cell In[75], line 31, in run_exam(oab_questions_df, model_name, N)
#      17 for index, row in tqdm(amostra_df.iterrows(), total=N, desc=f"Executando questões {model_name}"):
#      18     #print("\n" + "=" * 40)
#      19     #print(f"Questão {index}")
#      20     #print("-" * 40)
#      22     question_body = f'''
#      23     {row['enunciado']}
#      24
#    (...)
#      28     D) {row['D']}
#      29     '''
# ---> 31     response = model.generate_content(prompt_text + "\n" + question_body)
#      32     resposta_texto = response.text
#      33     answer = parse_answer(resposta_texto)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     152 # pylint: disable=broad-except
#     153 # This function explicitly must deal with broad exceptions.
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#     167     time.sleep(next_sleep)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\api_core\retry\retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     208 if not predicate_fn(exc):
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#     216     on_error_fn(exc)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\api_core\grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 50
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 1
# }
# ]
