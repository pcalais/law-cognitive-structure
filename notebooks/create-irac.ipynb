# %%
'''
prompt:
Gere codigo python que se conecta na API do Gemini e submete um prompt.
'''
# Out:
# '\nprompt:\nGere codigo python que se conecta na API do Gemini e submete um prompt.\n'

# %%
pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.8.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-api-python-client in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.174.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.40.3)
# Requirement already satisfied: protobuf in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.6.1)
# Requirement already satisfied: tqdm in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (4.66.1)
# Requirement already satisfied: typing-extensions in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core->google-generativeai) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic->google-generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic->google-generativeai) (2.16.2)
# Requirement already satisfied: colorama in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.73.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\pedro\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import google.generativeai as genai

# Substitua pela sua chave de API
API_KEY = "AIzaSyCXAuCP5LWl4Bk5i-6Ha-EX6NxnU8QxDNY"

model_name = "gemini-2.5-flash"

# Configura a API
genai.configure(api_key=API_KEY)

# Cria o modelo
model = genai.GenerativeModel(model_name)

# Submete o prompt
prompt = "Explique a teoria da relatividade em termos simples"
response = model.generate_content(prompt)

# Exibe a resposta
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[88], line 16
#      14 # Submete o prompt
#      15 prompt = "Explique a teoria da relatividade em termos simples"
# ---> 16 response = model.generate_content(prompt)
#      18 # Exibe a resposta
#      19 print(response.text)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     152 # pylint: disable=broad-except
#     153 # This function explicitly must deal with broad exceptions.
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#     167     time.sleep(next_sleep)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\api_core\retry\retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     208 if not predicate_fn(exc):
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#     216     on_error_fn(exc)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\api_core\grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 21
# }
# ]

# %%
import pandas as pd

# Caminho para o arquivo CSV
caminho_csv = "../data/interim/oab.csv"  

# Lê o CSV em um DataFrame
oab_questions_df = pd.read_csv(caminho_csv)

# Visualiza as primeiras linhas
oab_questions_df.head()
# Out:
#       question_id pdf_filename    prova                 materia  \
# 0   oab-1.pdf-001    oab-1.pdf       XV      ÉTICA PROFISSIONAL
# 1  oab-86.pdf-001   oab-86.pdf  INÉDITA       DIREITO ELEITORAL
# 2  oab-76.pdf-001   oab-76.pdf      XIV        DIREITOS HUMANOS
# 3  oab-46.pdf-001   oab-46.pdf       XV  DIREITO CONSTITUCIONAL
# 4  oab-39.pdf-001   oab-39.pdf      XIV               FILOSOFIA
#
#                                                tema  questao  \
# 0                   INCOMPATIBILIDADE E IMPEDIMENTO        1
# 1                               DIREITO DE SUFRÁGIO        1
# 2  DIREITOS HUMANOS NA CONSTITUIÇÃO FEDERAL DE 1988        1
# 3                           ORGANIZAÇÃO DOS PODERES        1
# 4                  PRINCIPAIS CORRENTES FILOSÓFICAS        1
#
#                                            enunciado  \
# 0  Abelardo é magistrado vinculado ao Tribunal de...
# 1  A verificação da idade mínima constitucionalme...
# 2  Em maio de 1996, o Brasil instituiu seu primei...
# 3  O senador “X” ausentou-se das atividades do Se...
# 4  O filósofo inglês Jeremy Bentham, em seu livro...
#
#                                                    A  \
# 0  A incompatibilidade com a advocacia persiste m...
# 1   do protocolo do pedido de registro de candidato.
# 2  havendo indício de violação de direitos humano...
# 3  A perda do mandato do referido senador será de...
# 4  estabelece que a moral e a lei devem ser obede...
#
#                                      justificativa_A  \
# 0  Afirmação falsa. Após a aposentadoria do juiz,...
# 1  Afirmação falsa. A verificação da idade mínima...
# 2  Afirmação falsa. Em caso de grave violação de ...
# 3  Afirmativa falsa. A perda do mandato de senado...
# 4  Afirmação falsa. A ideia de utilitarismo vai a...
#
#                                                    B  \
# 0  O afastamento temporário do cargo que gera a i...
# 1  do julgamento do pedido de registro de candidato.
# 2  havendo grave violação de direitos humanos pre...
# 3  Não poderá o referido parlamentar perder o man...
# 4  aprova ou desaprova qualquer ação, segundo a t...
#
#                                      justificativa_B  \
# 0  Afirmação falsa. A incompatibilidade persiste ...
# 1  Afirmação falsa. A verificação da idade mínima...
# 2  Alternativa correta. Trata-se do previsto no a...
# 3  Afirmação falsa. Permite-se o afastamento de s...
# 4  Alternativa correta. O Utilitarismo de Bentham...
#
#                                                    C  \
# 0  A incompatibilidade permanece mesmo que ocorra...
# 1                                      das eleições.
# 2  havendo violação das leis protetivas dos direi...
# 3  A perda do mandato do referido senador poderá ...
# 4  demonstra que o direito natural é superior ao ...
#
#                                      justificativa_C  \
# 0  Alternativa correta. Conforme o art. 28, §1º, ...
# 1  Afirmação falsa. Vide comentário à alternativa D.
# 2  Afirmação falsa. Conforme afirmado nos comentá...
# 3  Alternativa correta. A perda do mandato de sen...
# 4  Afirmação falsa. É o Jusnaturalismo que, ao es...
#
#                                                    D  \
# 0  O afastamento do cargo incompatível permite a ...
# 1                                          da posse.
# 2  havendo grave violação dos direitos humanos pr...
# 3  Caso o referido senador venha a renunciar após...
# 4  afirma que a liberdade humana é o bem maior a ...
#
#                                      justificativa_D correct
# 0  Afirmação falsa. Não há qualquer previsão lega...       C
# 1  Alternativa correta. Segundo o art. 11, §2º da...       D
# 2  Afirmação falsa. Não basta que os direitos hum...       B
# 3  Afirmação falsa. Não há arquivamento do proces...       C
# 4  Afirmação falsa. Diversos filósofos já se debr...       B

# %%
# Caminho para o arquivo
caminho_prompt = "prompts/generate_irac_prompt.txt"

# Lê o conteúdo do arquivo como string
with open(caminho_prompt, "r", encoding="utf-8") as arquivo:
    prompt_text = arquivo.read()

# Exibe parte do conteúdo
print(prompt_text)  # Mostra os primeiros 500 caracteres
# Out:
# A partir da questão da OAB e da resolução comentada a seguir, extraia do problema jurídico a estrutura IRAC (Issue, Rule, Application, Conclusion).
#
# Em "Rule", liste todas as doutrinas, princípios, leis e dispositivos constitucionais citados na resolução comentada. Não mencione nenhuma alternativa da questão explicitamente.
#
# A saída deve ser em formato JSON com as chaves "Issue", "Rule", "Application" e "Conclusion".
#
# A chave "Rule" deve ter sub-chaves: "constituicao_federal", "codigo_penal", "codigo_processo_penal", "clt", "codigo_civil", "codigo_processo_civil", "codigo_direito_consumidor", "estatuto_crianca_adolescente", "sumula_stj", "estatuto_oab", "codigo_tributario_nacional", "principio_geral_do_direito" e "outros".
#
# Para cada uma dessas sub-chaves, adicione a chave "lei", com o número, parágrafo, artigo ou inciso da lei, exemplo, "Art. 194 da Constituição Federal de 1988", e uma chave "conteudo", com o conteúdo da lei que a resolução comentada por ventura detalhe, como ""A seguridade social compreende um conjunto integrado de ações de iniciativa dos Poderes Públicos e da sociedade, destinadas a assegurar os direitos relativos à saúde, à previdência e à assistência social.".

# %%
import pandas as pd
import time
from tqdm import tqdm
import os
import json

def create_irac(oab_questions_df, model_name, N, output_path):
    total_questions = len(oab_questions_df)

    # Carrega resultados anteriores, se existirem
    if os.path.exists(output_path):
        existing_df = pd.read_csv(output_path)
        processed_keys = set(zip(existing_df['pdf_filename'], existing_df['questao']))
    else:
        existing_df = pd.DataFrame()
        processed_keys = set()

    # Cria chave única e filtra registros ainda não processados
    oab_questions_df['unique_key'] = list(zip(oab_questions_df['pdf_filename'], oab_questions_df['questao']))
    remaining_df = oab_questions_df[~oab_questions_df['unique_key'].isin(processed_keys)]

    # Estatísticas de progresso
    total_processed = len(processed_keys)
    total_remaining = len(remaining_df)
    pct_processed = (total_processed / total_questions) * 100
    pct_remaining = (total_remaining / total_questions) * 100

    print(f"Total de questões: {total_questions}")
    print(f"Já processadas: {total_processed} ({pct_processed:.1f}%)")
    print(f"Faltando: {total_remaining} ({pct_remaining:.1f}%)")

    # Se não há mais registros, retorna o DataFrame completo
    if remaining_df.empty:
        print("Todas as questões já foram processadas.")
        return existing_df

    # Seleciona N registros ainda não processados
    amostra_df = remaining_df.sample(n=min(N, total_remaining)).reset_index(drop=True)

    # Inicializa modelo
    genai.configure(api_key=API_KEY)
    model = genai.GenerativeModel(model_name)

    new_answers_df = pd.DataFrame()

    for index, row in tqdm(amostra_df.iterrows(), total=len(amostra_df), desc=f"Executando questões {model_name}"):
        question_body = f'''
        {row['enunciado']}

        A) {row['A']}.Gabarito comentado: {row['justificativa_A']}
        B) {row['B']} Gabarito comentado: {row['justificativa_B']}
        C) {row['C']} Gabarito comentado: {row['justificativa_C']}
        D) {row['D']} Gabarito comentado: {row['justificativa_D']}
        '''

        response = model.generate_content(prompt_text + "\n" + question_body)
        resposta_texto = response.text


        # Tenta fazer parsing do JSON da resposta
        try:
            irac = json.loads(resposta_texto.replace("```json", "").replace("```", ""))
            issue = irac.get("Issue", "")
            rule = irac.get("Rule", "")
            application = irac.get("Application", "")
            conclusion = irac.get("Conclusion", "")
        except Exception as e:
            print(f"[Erro no parsing JSON] questão {row['questao']}: {e}", resposta_texto)
            issue = rule = application = conclusion = ""
            rule = "{}"

        new_answers_df = pd.concat([
            new_answers_df,
            pd.DataFrame([{
                "question_id": row['question_id'],
                "pdf_filename": row['pdf_filename'],
                "materia": row['materia'],
                "prova": row['prova'],
                "questao": row['questao'],
                "enunciado": row['enunciado'],
                "A": row['A'],
                "justificativa_A": row['justificativa_A'],
                "B": row['B'],
                "justificativa_B": row['justificativa_B'],
                "C": row['C'],
                "justificativa_C": row['justificativa_C'],
                "D": row['D'],
                "justificativa_D": row['justificativa_D'],
                "Issue": issue,
                "Rule": json.dumps(rule),
                "Application": application,
                "Conclusion": conclusion,
                "correct": row['correct']
            }])
        ], ignore_index=True)

        time.sleep(5)

    # Salva resultados atualizados
    updated_df = pd.concat([existing_df, new_answers_df], ignore_index=True)
    updated_df.to_csv(output_path, index=False, encoding='utf-8-sig')

    return updated_df

# %%
# https://ai.google.dev/gemini-api/docs/rate-limits
N = 50
output_path = "../data/processed/oab_with_irac.csv"
oab_with_irac_df = create_irac(oab_questions_df, "gemini-2.5-flash-lite-preview-06-17", N, output_path)
# Out:
# Total de questões: 3422
# Já processadas: 0 (0.0%)
# Faltando: 3422 (100.0%)
# Executando questões gemini-2.5-flash-lite-preview-06-17: 100%|██████████| 50/50 [05:38<00:00,  6.77s/it]

# %%
# Função recursiva para coletar todas as ocorrências da chave "lei"
def encontrar_todas_leis(json_string):
    dados = json.loads(json_string)
    leis_encontradas = []

    for categoria in dados.values():
        if categoria == None:
            continue
        for item in categoria:
            if isinstance(item, dict) and "lei" in item:
                leis_encontradas.append(item["lei"])

    return leis_encontradas


rule = """
{"constituicao_federal": [{"lei": "lei tal da CF"}], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [{"lei": "Art. 733 do C\u00f3digo Civil", "conteudo": "Nos contratos de transporte cumulativo, cada transportador se obriga a cumprir o contrato relativamente ao respectivo percurso, respondendo pelos danos nele causados a pessoas e coisas."}], "codigo_processo_civil": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"lei": "Art. 2\u00ba da Lei n\u00ba 9.611/98", "conteudo": "Transporte Multimodal de Cargas \u00e9 aquele que, regido por um \u00fanico contrato, utiliza duas ou mais modalidades de transporte, desde a origem at\u00e9 o destino."}, {"lei": "Conceito de Contrato de Transporte Combinado", "conteudo": "No contrato de transporte combinado o transportador assume a obriga\u00e7\u00e3o de transportar a coisa no seu trecho, assumindo, perante o cliente, a obriga\u00e7\u00e3o de contratar terceiros para a continua\u00e7\u00e3o do transporte em outros trechos."}, {"lei": "Conceito de Transporte de Fato", "conteudo": "O transporte de fato se d\u00e1 quando realizado por pessoa distinta do transportador constante do contrato, autorizado por este a efetuar o transporte integral ou parcialmente."}]}
"""
assert len(encontrar_todas_leis(rule)) == 5
assert len(encontrar_todas_leis("{}")) == 0
assert len(encontrar_todas_leis("""{"constituicao_federal": null, "codigo_penal": null}""")) == 0

# %%
oab_with_irac_df.shape
# Out:
# (50, 19)

# %%
import pandas as pd
import json
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Converter a coluna 'Rule' (string JSON) para dicionário Python
oab_with_irac_df["Rule_dict"] = oab_with_irac_df["Rule"].apply(json.loads)

# 2. Contar o número de leis por fonte do direito (nível 1 do JSON)
def contar_leis_por_fonte(rule_dict):
    return {fonte: len(itens) for fonte, itens in rule_dict.items() if isinstance(itens, list)}

oab_with_irac_df["leis_por_fonte"] = oab_with_irac_df["Rule_dict"].apply(contar_leis_por_fonte)

# 3. Expandir a coluna 'leis_por_fonte' em colunas separadas
leis_df = oab_with_irac_df[["materia", "leis_por_fonte"]].copy()
leis_expandidas = leis_df["leis_por_fonte"].apply(pd.Series)
leis_expandidas["materia"] = leis_df["materia"]

# 4. Agrupar por matéria e calcular a média de leis por fonte
media_leis_por_materia = leis_expandidas.groupby("materia").mean(numeric_only=True)

# 5. Calcular o total médio de leis por matéria e ordenar
media_leis_por_materia["total_medio"] = media_leis_por_materia.sum(axis=1)
media_leis_por_materia = media_leis_por_materia.sort_values("total_medio", ascending=False)
media_leis_ordenadas = media_leis_por_materia.drop(columns="total_medio")

# 6. Plotar o heatmap ordenado
plt.figure(figsize=(12, 6))
sns.heatmap(media_leis_ordenadas, annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("Número médio de leis por fonte do direito e por matéria (ordenado)")
plt.xlabel("Fonte primária do direito (1º nível do JSON)")
plt.ylabel("Matéria")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import json
import random

# Carrega o DataFrame
oab_with_irac_df = pd.read_csv("../data/processed/oab_with_irac.csv")

dataframes_por_linha = []
num_linhas = len(oab_with_irac_df)
indices = list(range(num_linhas))

for idx, row in oab_with_irac_df.iterrows():
    nova_linha = row.copy()

    # Extrai "lei" da linha atual para a coluna A
    rule_data = row['Rule']
    leis_A = encontrar_todas_leis(rule_data)
    nova_linha['A'] = '; '.join(str(lei) for lei in leis_A) if leis_A else ''

    # Filtra índices com a mesma matéria (exceto o atual)
    materia_atual = row['materia']
    mesma_materia_indices = oab_with_irac_df[
        (oab_with_irac_df['materia'] == materia_atual) & (oab_with_irac_df.index != idx)
    ].index.tolist()


    # Se houver ao menos 3, usa eles; senão, usa quaisquer outros
    if len(mesma_materia_indices) >= 3:
        aleatorios = random.sample(mesma_materia_indices, 3)
    else:
        possiveis_indices = [i for i in indices if i != idx]
        aleatorios = random.sample(possiveis_indices, 3)

    # Preenche colunas B, C e D
    for col, i_aleatorio in zip(['B', 'C', 'D'], aleatorios):
        rule_aleatorio = oab_with_irac_df.loc[i_aleatorio, 'Rule']
        leis_aleatorias = encontrar_todas_leis(rule_aleatorio)
        valor_concat = '; '.join(str(lei) for lei in leis_aleatorias) if leis_aleatorias else ''
        nova_linha[col] = valor_concat

    df_novo = pd.DataFrame([nova_linha])
    dataframes_por_linha.append(df_novo)

# Junta tudo e salva
df_testa_lei = pd.concat(dataframes_por_linha, ignore_index=True)
df_testa_lei['correct'] = 'A'
df_testa_lei.to_csv("../data/processed/oab_guess_the_rule.csv", index=False, encoding='utf-8-sig')
# Out:
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"lei": "Lei n\u00ba 9.279/96, Art. 6\u00ba, \u00a72\u00ba", "conteudo": "A patente poder\u00e1 ser requerida em nome pr\u00f3prio, pelos herdeiros ou sucessores do autor, pelo cession\u00e1rio ou por aquele a quem a lei ou o contrato de trabalho ou de presta\u00e7\u00e3o de servi\u00e7os determinar que perten\u00e7a a titularidade."}]}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"lei": "Art. 4\u00ba da Lei n\u00ba 6.404/76", "conteudo": "A companhia ser\u00e1 aberta ou fechada conforme os valores mobili\u00e1rios de sua emiss\u00e3o sejam admitidos ou n\u00e3o \u00e0 negocia\u00e7\u00e3o no mercado de bolsa ou de balc\u00e3o."}, {"lei": "Art. 47, par\u00e1grafo \u00fanico, da Lei n\u00ba 6.404/76", "conteudo": "A companhia aberta n\u00e3o pode emitir partes benefici\u00e1rias."}, {"lei": "Art. 36 da Lei n\u00ba 6.404/76", "conteudo": "O estatuto da companhia fechada pode impor limita\u00e7\u00f5es \u00e0 circula\u00e7\u00e3o das a\u00e7\u00f5es nominativas, o que inclui as a\u00e7\u00f5es ordin\u00e1rias e preferenciais."}, {"lei": "Art. 15, \u00a71\u00ba, da Lei n\u00ba 6.404/76", "conteudo": "As a\u00e7\u00f5es ordin\u00e1rias da companhia fechada e as a\u00e7\u00f5es preferenciais da companhia aberta e fechada poder\u00e3o ser de uma ou mais classes."}]}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"lei": "Art. 6\u00ba, \u00a7 8\u00ba, da Lei n\u00ba 11.101/2005", "conteudo": "A distribui\u00e7\u00e3o do pedido de fal\u00eancia ou de recupera\u00e7\u00e3o judicial ou a homologa\u00e7\u00e3o de recupera\u00e7\u00e3o extrajudicial previne a jurisdi\u00e7\u00e3o para qualquer outro pedido de fal\u00eancia, de recupera\u00e7\u00e3o judicial ou de homologa\u00e7\u00e3o de recupera\u00e7\u00e3o extrajudicial relativo ao mesmo devedor."}]}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": {"lei": "Art. 932 do CPC/2015 (antigo art. 557 do CPC/73)", "conteudo": "O relator poder\u00e1 julgar o recurso monocraticamente."}, "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [{"lei": "Princ\u00edpio da Fungibilidade", "conteudo": "Permite a interposi\u00e7\u00e3o de um recurso por outro, desde que preenchidos os requisitos legais e n\u00e3o haja erro grosseiro."}, {"lei": "Princ\u00edpio da Celeridade Processual", "conteudo": "Visa a dar tramita\u00e7\u00e3o mais r\u00e1pida aos processos, evitando a morosidade judicial."}], "outros": [{"lei": "S\u00famula n\u00ba 435 do TST", "conteudo": "Permite a aplica\u00e7\u00e3o subsidi\u00e1ria do art. 932 do CPC (antigo art. 557 do CPC/73) no \u00e2mbito da Justi\u00e7a do Trabalho, autorizando o julgamento monocr\u00e1tico pelo relator."}, {"lei": "S\u00famula n\u00ba 421 do TST", "conteudo": "Disp\u00f5e que da decis\u00e3o monocr\u00e1tica do relator caber\u00e1 embargos de declara\u00e7\u00e3o, e caso se pretenda efeito modificativo, os embargos dever\u00e3o ser submetidos ao Colegiado, convertidos em agravo."}]}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [{"lei": "Art. 852-A da CLT", "conteudo": "O procedimento sumar\u00edssimo \u00e9 aplic\u00e1vel nas reclama\u00e7\u00f5es trabalhistas que n\u00e3o excedam a dois sal\u00e1rios m\u00ednimos."}, {"lei": "Art. 852-H, \u00a7 2\u00ba, da CLT", "conteudo": "Em procedimento sumar\u00edssimo, cada parte poder\u00e1 indicar, no m\u00e1ximo, duas testemunhas."}, {"lei": "Art. 852-A, par\u00e1grafo \u00fanico da CLT", "conteudo": "Est\u00e3o exclu\u00eddas do procedimento sumar\u00edssimo as demandas em que \u00e9 parte a Administra\u00e7\u00e3o P\u00fablica direta, aut\u00e1rquica e fundacional."}], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
# rule_aleatorio {"constituicao_federal": null, "codigo_penal": null, "codigo_processo_penal": null, "clt": [{"lei": "Art. 879, caput, da CLT", "conteudo": "Estabelece que existem tr\u00eas modalidades de liquida\u00e7\u00e3o: c\u00e1lculos, arbitramento e artigos."}, {"lei": "Art. 879, \u00a72\u00ba, da CLT", "conteudo": "O prazo para a impugna\u00e7\u00e3o da liquida\u00e7\u00e3o da senten\u00e7a passou a ser de 8 dias."}], "codigo_civil": null, "codigo_processo_civil": null, "codigo_direito_consumidor": null, "estatuto_crianca_adolescente": null, "sumula_stj": null, "estatuto_oab": null, "codigo_tributario_nacional": null, "principio_geral_do_direito": null, "outros": null}
# rule_aleatorio {"constituicao_federal": [{"lei": "Art. 71, VI, da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "O Tribunal de Contas da Uni\u00e3o, integrado ao sistema de controle externo, exercer\u00e1 a fiscaliza\u00e7\u00e3o cont\u00e1bil, financeira, or\u00e7ament\u00e1ria, operacional e patrimonial da Uni\u00e3o e das entidades da administra\u00e7\u00e3o direta e indireta, quanto \u00e0 legalidade, legitimidade e economicidade e \u00e0 aplica\u00e7\u00e3o das subven\u00e7\u00f5es e ren\u00fancias tribut\u00e1rias. A aplica\u00e7\u00e3o de quaisquer recursos repassados pela Uni\u00e3o mediante conv\u00eanio, acordo, ajuste ou outros instrumentos cong\u00eaneres, a Estado, ao Distrito Federal ou a Munic\u00edpio."}, {"lei": "Art. 71, IX, da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "O Tribunal de Contas da Uni\u00e3o, integrado ao sistema de controle externo, exercer\u00e1 a fiscaliza\u00e7\u00e3o cont\u00e1bil, financeira, or\u00e7ament\u00e1ria, operacional e patrimonial da Uni\u00e3o e das entidades da administra\u00e7\u00e3o direta e indireta, quanto \u00e0 legalidade, legitimidade e economicidade e \u00e0 aplica\u00e7\u00e3o das subven\u00e7\u00f5es e ren\u00fancias tribut\u00e1rias. Assinar prazo para que o \u00f3rg\u00e3o ou entidade adote as provid\u00eancias necess\u00e1rias ao exato cumprimento da lei, se verificada ilegalidade."}], "codigo_penal": null, "codigo_processo_penal": null, "clt": null, "codigo_civil": null, "codigo_processo_civil": null, "codigo_direito_consumidor": null, "estatuto_crianca_adolescente": null, "sumula_stj": null, "estatuto_oab": null, "codigo_tributario_nacional": null, "principio_geral_do_direito": null, "outros": []}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [{"lei": "Art. 78 do CTN", "conteudo": "O poder de pol\u00edcia, quando exercido no interesse p\u00fablico, pode gerar a cobran\u00e7a de taxa, que representa uma contrapresta\u00e7\u00e3o estatal."}], "principio_geral_do_direito": [{"lei": "Princ\u00edpio da Razoabilidade", "conteudo": "O princ\u00edpio da razoabilidade atua como um limite ao exerc\u00edcio do poder de pol\u00edcia, impedindo excessos da Administra\u00e7\u00e3o P\u00fablica em prol do interesse p\u00fablico."}], "outros": [{"lei": "Doutrina do Poder de Pol\u00edcia", "conteudo": "O poder de pol\u00edcia \u00e9 a prerrogativa do Estado de limitar ou restringir a liberdade individual ou o direito de propriedade em benef\u00edcio do interesse p\u00fablico. Pode se instrumentalizar por meio de atos normativos (decretos, portarias, resolu\u00e7\u00f5es, instru\u00e7\u00f5es) e n\u00e3o apenas por alvar\u00e1s de autoriza\u00e7\u00e3o. A sua atua\u00e7\u00e3o deve sempre ocorrer nos limites da lei."}]}
# rule_aleatorio {"constituicao_federal": [{"lei": "Art. 37, inciso II, da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "A investidura em cargo ou emprego p\u00fablico depende de aprova\u00e7\u00e3o em concurso p\u00fablico com cl\u00e1usula de aprova\u00e7\u00e3o em todas as fases do concurso."}, {"lei": "Art. 37, inciso XI, da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "Aplica-se aos servidores p\u00fablicos e aos militares de todos os n\u00edveis da Administra\u00e7\u00e3o P\u00fablica o disposto no inciso XIII do art. 37, bem como as disposi\u00e7\u00f5es de leis que concederem ou determinarem remunera\u00e7\u00e3o superior \u00e0 prevista no mesmo inciso."}, {"lei": "Art. 173, \u00a7 1\u00ba, inciso II, da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "No entanto, a lei estabelecer\u00e1 o regime jur\u00eddico e o prazo de dura\u00e7\u00e3o dos contratos, bem como normas sobre responsabilidade civil, administrativa e penal dos seus dirigentes e empregados, para os crimes definidos em lei, quando praticados no exerc\u00edcio das suas fun\u00e7\u00f5es, ou quando de sua inobserv\u00e2ncia resultar preju\u00edzo para a Fazenda P\u00fablica."}], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"lei": "Posicionamento do STF", "conteudo": "O STF j\u00e1 definiu que \u00e9 obrigat\u00f3ria a motiva\u00e7\u00e3o da dispensa unilateral de empregado p\u00fablico."}]}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": {"lei": "Art. 932 do CPC/2015 (antigo art. 557 do CPC/73)", "conteudo": "O relator poder\u00e1 julgar o recurso monocraticamente."}, "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [{"lei": "Princ\u00edpio da Fungibilidade", "conteudo": "Permite a interposi\u00e7\u00e3o de um recurso por outro, desde que preenchidos os requisitos legais e n\u00e3o haja erro grosseiro."}, {"lei": "Princ\u00edpio da Celeridade Processual", "conteudo": "Visa a dar tramita\u00e7\u00e3o mais r\u00e1pida aos processos, evitando a morosidade judicial."}], "outros": [{"lei": "S\u00famula n\u00ba 435 do TST", "conteudo": "Permite a aplica\u00e7\u00e3o subsidi\u00e1ria do art. 932 do CPC (antigo art. 557 do CPC/73) no \u00e2mbito da Justi\u00e7a do Trabalho, autorizando o julgamento monocr\u00e1tico pelo relator."}, {"lei": "S\u00famula n\u00ba 421 do TST", "conteudo": "Disp\u00f5e que da decis\u00e3o monocr\u00e1tica do relator caber\u00e1 embargos de declara\u00e7\u00e3o, e caso se pretenda efeito modificativo, os embargos dever\u00e3o ser submetidos ao Colegiado, convertidos em agravo."}]}
# rule_aleatorio {"constituicao_federal": {"lei": null, "conteudo": null}, "codigo_penal": {"lei": null, "conteudo": null}, "codigo_processo_penal": {"lei": null, "conteudo": null}, "clt": {"lei": null, "conteudo": null}, "codigo_civil": {"lei": null, "conteudo": null}, "codigo_processo_civil": {"lei": null, "conteudo": null}, "codigo_direito_consumidor": {"lei": null, "conteudo": null}, "estatuto_crianca_adolescente": {"lei": null, "conteudo": null}, "sumula_stj": {"lei": null, "conteudo": null}, "estatuto_oab": {"lei": null, "conteudo": null}, "codigo_tributario_nacional": {"lei": null, "conteudo": null}, "principio_geral_do_direito": {"lei": null, "conteudo": null}, "outros": [{"lei": "Obra Filosofia do Direito de Miguel Reale", "conteudo": "A Escola da Exegese entendia que o Direito \u00e9 revelado exclusivamente pelas leis escritas emanadas do Estado, consideradas fontes \u00fanicas de faculdades e obriga\u00e7\u00f5es jur\u00eddicas. O enfoque era a aplica\u00e7\u00e3o literal da lei vigente, com car\u00e1ter estritamente gramatical, sem buscar o ideal de justi\u00e7a, limitar a liberdade legislativa com valores superiores, fins sociais ou o bem comum."}]}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [{"lei": "Art. 44, I, do CP", "conteudo": "Tratando-se de crime praticado com viol\u00eancia \u00e0 pessoa, n\u00e3o \u00e9 poss\u00edvel a substitui\u00e7\u00e3o da pena privativa de liberdade por restritiva de direitos."}, {"lei": "Art. 77 do CP", "conteudo": "Suspender a execu\u00e7\u00e3o da pena privativa de liberdade por um determinado per\u00edodo (per\u00edodo de prova), em que ficar\u00e1 sujeito a determinadas condi\u00e7\u00f5es que, se cumpridas, acarretar\u00e3o a extin\u00e7\u00e3o da punibilidade do agente."}], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"lei": "Lei n\u00ba 11.340/2006 (Lei Maria da Penha)", "conteudo": "Configura viol\u00eancia dom\u00e9stica e familiar contra a mulher qualquer a\u00e7\u00e3o ou omiss\u00e3o baseada no g\u00eanero que lhe cause morte, les\u00e3o, sofrimento f\u00edsico, sexual ou psicol\u00f3gico e dano moral ou patrimonial, inclusive em qualquer rela\u00e7\u00e3o \u00edntima de afeto, na qual o agressor conviva ou tenha convivido com a ofendida, independentemente de coabita\u00e7\u00e3o."}, {"lei": "Art. 41 Lei n. 11.340/2006", "conteudo": "O crime ser\u00e1 processado mediante a\u00e7\u00e3o penal p\u00fablica incondicionada."}, {"lei": "Art. 89 da Lei n. 9.099/95", "conteudo": "Prev\u00ea a suspens\u00e3o condicional do processo, que n\u00e3o se aplica aos casos de viol\u00eancia dom\u00e9stica e familiar contra a mulher (Lei Maria da Penha)."}]}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"lei": "Lei n\u00ba 12.651/2012, Art. 29, caput e \u00a7 2\u00ba", "conteudo": "O Cadastro Ambiental Rural (CAR) \u00e9 obrigat\u00f3rio para todos os im\u00f3veis rurais do Brasil. O CAR consiste em um registro p\u00fablico eletr\u00f4nico de \u00e2mbito nacional, com a finalidade de integrar as informa\u00e7\u00f5es ambientais das propriedades e posses rurais, compondo base de dados para controle, monitoramento, planejamento ambiental e econ\u00f4mico e combate ao desmatamento. O registro no CAR n\u00e3o \u00e9 considerado t\u00edtulo para fins de reconhecimento do direito de propriedade ou posse."}]}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [{"lei": "Art. 119 do CPC/2015", "conteudo": "Pendendo causa entre 2 (duas) ou mais pessoas, o terceiro juridicamente interessado em que a senten\u00e7a seja favor\u00e1vel a uma delas poder\u00e1 intervir no processo para assisti-la."}, {"lei": "Art. 130 do CPC/2015", "conteudo": "O chamamento ao processo \u00e9 admiss\u00edvel nas seguintes hip\u00f3teses: I - do afian\u00e7ado, na a\u00e7\u00e3o em que o fiador for r\u00e9u; II - dos demais fiadores, na a\u00e7\u00e3o proposta contra um ou alguns deles; III - dos demais devedores solid\u00e1rios, quando o credor exigir de um ou de alguns o pagamento da d\u00edvida comum."}, {"lei": "Art. 125, II, do CPC/2015", "conteudo": "A denuncia\u00e7\u00e3o \u00e0 lide \u00e9 admitida a todo aquele que estiver obrigado, pela lei ou pelo contrato, a indenizar, no todo ou em parte, o preju\u00edzo do que perdeu, ou seja, se o denunciante for o r\u00e9u. Ao mesmo tempo, o denunciado pode ser denunciado pelo autor."}], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [{"lei": "Art. 2\u00ba, caput, do CP", "conteudo": "Ningu\u00e9m pode ser punido por fato que lei posterior deixa de considerar crime, cessando em virtude dela a execu\u00e7\u00e3o e os efeitos penais da senten\u00e7a condenat\u00f3ria."}], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
# rule_aleatorio {"constituicao_federal": {}, "codigo_penal": {"lei": "Art. 317 do C\u00f3digo Penal", "conteudo": "Solicitar ou receber, para si ou para outrem, direta ou indiretamente, ainda que fora da fun\u00e7\u00e3o ou antes de assumi-la, mas em raz\u00e3o dela, vantagem indevida, ou aceitar promessa de tal vantagem."}, "codigo_processo_penal": {}, "clt": {}, "codigo_civil": {}, "codigo_processo_civil": {}, "codigo_direito_consumidor": {}, "estatuto_crianca_adolescente": {}, "sumula_stj": {}, "estatuto_oab": {}, "codigo_tributario_nacional": {}, "principio_geral_do_direito": {}, "outros": {"lei": "Art. 327 do C\u00f3digo Penal", "conteudo": "Considera-se funcion\u00e1rio p\u00fablico, para efeitos penais, quem, embora transitoriamente ou sem remunera\u00e7\u00e3o, exerce cargo, emprego ou fun\u00e7\u00e3o p\u00fablica. Equipara-se a funcion\u00e1rio p\u00fablico quem exerce cargo, emprego ou fun\u00e7\u00e3o em entidade paraestatal, e quem trabalha para empresa prestadora de servi\u00e7o contratada ou conveniada para a execu\u00e7\u00e3o de atividade t\u00edpica da Administra\u00e7\u00e3o P\u00fablica."}}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [{"lei": "Art. 157, \u00a7 3\u00ba do C\u00f3digo Penal", "conteudo": "Subtrair coisa m\u00f3vel alheia, para si ou para outrem, mediante grave amea\u00e7a ou viol\u00eancia a pessoa, ou depois de hav\u00ea-la, por qualquer meio, reduzido \u00e0 impossibilidade de resist\u00eancia; \u00a7 3\u00ba - Se da viol\u00eancia resulta les\u00e3o corporal grave, a pena \u00e9 de reclus\u00e3o, de sete a quinze anos, al\u00e9m da multa; se resulta morte, a reclus\u00e3o \u00e9 de vinte a trinta anos, sem preju\u00edzo da multa."}, {"lei": "Art. 155 do C\u00f3digo Penal", "conteudo": "Subtrair, para si ou para outrem, coisa alheia m\u00f3vel."}, {"lei": "Art. 121, \u00a7 2\u00ba, V do C\u00f3digo Penal", "conteudo": "Matar algu\u00e9m: \u00a7 2\u00ba - Se o homic\u00eddio \u00e9 cometido: V - para assegurar a execu\u00e7\u00e3o, a oculta\u00e7\u00e3o, a impunidade ou vantagem de outro crime:"}], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [{"lei": "Art. 44, I, do CP", "conteudo": "Tratando-se de crime praticado com viol\u00eancia \u00e0 pessoa, n\u00e3o \u00e9 poss\u00edvel a substitui\u00e7\u00e3o da pena privativa de liberdade por restritiva de direitos."}, {"lei": "Art. 77 do CP", "conteudo": "Suspender a execu\u00e7\u00e3o da pena privativa de liberdade por um determinado per\u00edodo (per\u00edodo de prova), em que ficar\u00e1 sujeito a determinadas condi\u00e7\u00f5es que, se cumpridas, acarretar\u00e3o a extin\u00e7\u00e3o da punibilidade do agente."}], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"lei": "Lei n\u00ba 11.340/2006 (Lei Maria da Penha)", "conteudo": "Configura viol\u00eancia dom\u00e9stica e familiar contra a mulher qualquer a\u00e7\u00e3o ou omiss\u00e3o baseada no g\u00eanero que lhe cause morte, les\u00e3o, sofrimento f\u00edsico, sexual ou psicol\u00f3gico e dano moral ou patrimonial, inclusive em qualquer rela\u00e7\u00e3o \u00edntima de afeto, na qual o agressor conviva ou tenha convivido com a ofendida, independentemente de coabita\u00e7\u00e3o."}, {"lei": "Art. 41 Lei n. 11.340/2006", "conteudo": "O crime ser\u00e1 processado mediante a\u00e7\u00e3o penal p\u00fablica incondicionada."}, {"lei": "Art. 89 da Lei n. 9.099/95", "conteudo": "Prev\u00ea a suspens\u00e3o condicional do processo, que n\u00e3o se aplica aos casos de viol\u00eancia dom\u00e9stica e familiar contra a mulher (Lei Maria da Penha)."}]}
# rule_aleatorio {"constituicao_federal": [{"lei": "Art. 12, I, \"b\", da CF/88", "conteudo": "Os nascidos no estrangeiro de pai brasileiro ou de m\u00e3e brasileira, desde que estejam a servi\u00e7o da Rep\u00fablica Federativa do Brasil."}, {"lei": "Art. 12, I, \"c\", da CF/88", "conteudo": "Os nascidos no estrangeiro de pai brasileiro ou de m\u00e3e brasileira, desde que sejam registrados em reparti\u00e7\u00e3o brasileira competente ou venham a residir na Rep\u00fablica Federativa do Brasil e optem, em qualquer tempo, depois de atingida a maioridade, pela nacionalidade brasileira."}], "codigo_penal": {}, "codigo_processo_penal": {}, "clt": {}, "codigo_civil": {}, "codigo_processo_civil": {}, "codigo_direito_consumidor": {}, "estatuto_crianca_adolescente": {}, "sumula_stj": {}, "estatuto_oab": {}, "codigo_tributario_nacional": {}, "principio_geral_do_direito": {}, "outros": {}}
# rule_aleatorio {"constituicao_federal": {}, "codigo_penal": {}, "codigo_processo_penal": {}, "clt": {}, "codigo_civil": {}, "codigo_processo_civil": {}, "codigo_direito_consumidor": {}, "estatuto_crianca_adolescente": {}, "sumula_stj": {}, "estatuto_oab": {"lei": "Art. 55, \u00a7 1\u00ba, do C\u00f3digo de \u00c9tica e Disciplina da OAB/2015", "conteudo": "O processo disciplinar pode ser instaurado de of\u00edcio, quando o conhecimento do fato for obtido por meio de fonte id\u00f4nea ou em virtude de comunica\u00e7\u00e3o da autoridade competente."}, "codigo_tributario_nacional": {}, "principio_geral_do_direito": {}, "outros": [{"lei": "Art. 55, \u00a7 2\u00ba, do C\u00f3digo de \u00c9tica e Disciplina da OAB/2015", "conteudo": "O C\u00f3digo de \u00c9tica e Disciplina da OAB n\u00e3o admite a instaura\u00e7\u00e3o de processo disciplinar com fundamento em den\u00fancia an\u00f4nima."}]}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"lei": "Art. 6\u00ba, \u00a7 8\u00ba, da Lei n\u00ba 11.101/2005", "conteudo": "A distribui\u00e7\u00e3o do pedido de fal\u00eancia ou de recupera\u00e7\u00e3o judicial ou a homologa\u00e7\u00e3o de recupera\u00e7\u00e3o extrajudicial previne a jurisdi\u00e7\u00e3o para qualquer outro pedido de fal\u00eancia, de recupera\u00e7\u00e3o judicial ou de homologa\u00e7\u00e3o de recupera\u00e7\u00e3o extrajudicial relativo ao mesmo devedor."}]}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [{"lei": "Art. 119 do CPC/2015", "conteudo": "Pendendo causa entre 2 (duas) ou mais pessoas, o terceiro juridicamente interessado em que a senten\u00e7a seja favor\u00e1vel a uma delas poder\u00e1 intervir no processo para assisti-la."}, {"lei": "Art. 130 do CPC/2015", "conteudo": "O chamamento ao processo \u00e9 admiss\u00edvel nas seguintes hip\u00f3teses: I - do afian\u00e7ado, na a\u00e7\u00e3o em que o fiador for r\u00e9u; II - dos demais fiadores, na a\u00e7\u00e3o proposta contra um ou alguns deles; III - dos demais devedores solid\u00e1rios, quando o credor exigir de um ou de alguns o pagamento da d\u00edvida comum."}, {"lei": "Art. 125, II, do CPC/2015", "conteudo": "A denuncia\u00e7\u00e3o \u00e0 lide \u00e9 admitida a todo aquele que estiver obrigado, pela lei ou pelo contrato, a indenizar, no todo ou em parte, o preju\u00edzo do que perdeu, ou seja, se o denunciante for o r\u00e9u. Ao mesmo tempo, o denunciado pode ser denunciado pelo autor."}], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
# rule_aleatorio {"constituicao_federal": {}, "codigo_penal": {}, "codigo_processo_penal": {}, "clt": {}, "codigo_civil": {}, "codigo_processo_civil": {"lei": [{"artigo": "Art. 554", "conteudo": "A propositura de uma a\u00e7\u00e3o possess\u00f3ria em vez de outra n\u00e3o obstar\u00e1 a que o juiz conhe\u00e7a do pedido e outorgue a prote\u00e7\u00e3o legal correspondente \u00e0quela cujos pressupostos estejam provados."}, {"artigo": "Art. 555, I", "conteudo": "\u00c9 l\u00edcito o autor cumular o pedido possess\u00f3rio com condena\u00e7\u00e3o em perdas e danos."}, {"artigo": "Art. 556", "conteudo": "\u00c9 l\u00edcito ao r\u00e9u, na contesta\u00e7\u00e3o, alegando que foi o ofendido em sua posse, demandar a prote\u00e7\u00e3o possess\u00f3ria e a indeniza\u00e7\u00e3o pelos preju\u00edzos resultantes da turba\u00e7\u00e3o ou do esbulho cometido pelo autor."}, {"artigo": "Art. 567", "conteudo": "O possuidor direto ou indireto que tenha justo receio de ser molestado na posse poder\u00e1 requerer ao juiz que o segure da turba\u00e7\u00e3o ou esbulho iminente, mediante mandado proibit\u00f3rio em que se comine ao r\u00e9u determinada pena pecuni\u00e1ria caso transgrida o preceito."}]}, "codigo_direito_consumidor": {}, "estatuto_crianca_adolescente": {}, "sumula_stj": {}, "estatuto_oab": {}, "codigo_tributario_nacional": {}, "principio_geral_do_direito": [{"lei": "Princ\u00edpio da Adstri\u00e7\u00e3o", "conteudo": "Embora n\u00e3o explicitamente detalhado na resolu\u00e7\u00e3o, o princ\u00edpio da adstri\u00e7\u00e3o \u00e9 mencionado em rela\u00e7\u00e3o \u00e0 possibilidade do juiz deferir medida diversa da inicialmente pleiteada."}, {"lei": "Princ\u00edpio do Enriquecimento Sem Causa", "conteudo": "Este princ\u00edpio \u00e9 mencionado como um dos motivos para se refutar a impossibilidade de cumula\u00e7\u00e3o de pedidos, indicando que tal cumula\u00e7\u00e3o n\u00e3o caracterizaria enriquecimento sem causa."}], "outros": []}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": {"lei": "Art. 876 do CPC", "conteudo": "O credor poder\u00e1 adjudicar o bem penhorado, caso deposite a diferen\u00e7a entre o valor do bem e o montante da d\u00edvida. Essa quantia ficar\u00e1 \u00e0 disposi\u00e7\u00e3o do devedor."}, "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [{"lei": "Art. 44, I, do CP", "conteudo": "Tratando-se de crime praticado com viol\u00eancia \u00e0 pessoa, n\u00e3o \u00e9 poss\u00edvel a substitui\u00e7\u00e3o da pena privativa de liberdade por restritiva de direitos."}, {"lei": "Art. 77 do CP", "conteudo": "Suspender a execu\u00e7\u00e3o da pena privativa de liberdade por um determinado per\u00edodo (per\u00edodo de prova), em que ficar\u00e1 sujeito a determinadas condi\u00e7\u00f5es que, se cumpridas, acarretar\u00e3o a extin\u00e7\u00e3o da punibilidade do agente."}], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"lei": "Lei n\u00ba 11.340/2006 (Lei Maria da Penha)", "conteudo": "Configura viol\u00eancia dom\u00e9stica e familiar contra a mulher qualquer a\u00e7\u00e3o ou omiss\u00e3o baseada no g\u00eanero que lhe cause morte, les\u00e3o, sofrimento f\u00edsico, sexual ou psicol\u00f3gico e dano moral ou patrimonial, inclusive em qualquer rela\u00e7\u00e3o \u00edntima de afeto, na qual o agressor conviva ou tenha convivido com a ofendida, independentemente de coabita\u00e7\u00e3o."}, {"lei": "Art. 41 Lei n. 11.340/2006", "conteudo": "O crime ser\u00e1 processado mediante a\u00e7\u00e3o penal p\u00fablica incondicionada."}, {"lei": "Art. 89 da Lei n. 9.099/95", "conteudo": "Prev\u00ea a suspens\u00e3o condicional do processo, que n\u00e3o se aplica aos casos de viol\u00eancia dom\u00e9stica e familiar contra a mulher (Lei Maria da Penha)."}]}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [{"lei": "Art. 157, \u00a7 3\u00ba do C\u00f3digo Penal", "conteudo": "Subtrair coisa m\u00f3vel alheia, para si ou para outrem, mediante grave amea\u00e7a ou viol\u00eancia a pessoa, ou depois de hav\u00ea-la, por qualquer meio, reduzido \u00e0 impossibilidade de resist\u00eancia; \u00a7 3\u00ba - Se da viol\u00eancia resulta les\u00e3o corporal grave, a pena \u00e9 de reclus\u00e3o, de sete a quinze anos, al\u00e9m da multa; se resulta morte, a reclus\u00e3o \u00e9 de vinte a trinta anos, sem preju\u00edzo da multa."}, {"lei": "Art. 155 do C\u00f3digo Penal", "conteudo": "Subtrair, para si ou para outrem, coisa alheia m\u00f3vel."}, {"lei": "Art. 121, \u00a7 2\u00ba, V do C\u00f3digo Penal", "conteudo": "Matar algu\u00e9m: \u00a7 2\u00ba - Se o homic\u00eddio \u00e9 cometido: V - para assegurar a execu\u00e7\u00e3o, a oculta\u00e7\u00e3o, a impunidade ou vantagem de outro crime:"}], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
# rule_aleatorio {"constituicao_federal": {}, "codigo_penal": {"lei": "Art. 317 do C\u00f3digo Penal", "conteudo": "Solicitar ou receber, para si ou para outrem, direta ou indiretamente, ainda que fora da fun\u00e7\u00e3o ou antes de assumi-la, mas em raz\u00e3o dela, vantagem indevida, ou aceitar promessa de tal vantagem."}, "codigo_processo_penal": {}, "clt": {}, "codigo_civil": {}, "codigo_processo_civil": {}, "codigo_direito_consumidor": {}, "estatuto_crianca_adolescente": {}, "sumula_stj": {}, "estatuto_oab": {}, "codigo_tributario_nacional": {}, "principio_geral_do_direito": {}, "outros": {"lei": "Art. 327 do C\u00f3digo Penal", "conteudo": "Considera-se funcion\u00e1rio p\u00fablico, para efeitos penais, quem, embora transitoriamente ou sem remunera\u00e7\u00e3o, exerce cargo, emprego ou fun\u00e7\u00e3o p\u00fablica. Equipara-se a funcion\u00e1rio p\u00fablico quem exerce cargo, emprego ou fun\u00e7\u00e3o em entidade paraestatal, e quem trabalha para empresa prestadora de servi\u00e7o contratada ou conveniada para a execu\u00e7\u00e3o de atividade t\u00edpica da Administra\u00e7\u00e3o P\u00fablica."}}
# rule_aleatorio {"constituicao_federal": [{"lei": "Art. 71, VI, da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "O Tribunal de Contas da Uni\u00e3o, integrado ao sistema de controle externo, exercer\u00e1 a fiscaliza\u00e7\u00e3o cont\u00e1bil, financeira, or\u00e7ament\u00e1ria, operacional e patrimonial da Uni\u00e3o e das entidades da administra\u00e7\u00e3o direta e indireta, quanto \u00e0 legalidade, legitimidade e economicidade e \u00e0 aplica\u00e7\u00e3o das subven\u00e7\u00f5es e ren\u00fancias tribut\u00e1rias. A aplica\u00e7\u00e3o de quaisquer recursos repassados pela Uni\u00e3o mediante conv\u00eanio, acordo, ajuste ou outros instrumentos cong\u00eaneres, a Estado, ao Distrito Federal ou a Munic\u00edpio."}, {"lei": "Art. 71, IX, da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "O Tribunal de Contas da Uni\u00e3o, integrado ao sistema de controle externo, exercer\u00e1 a fiscaliza\u00e7\u00e3o cont\u00e1bil, financeira, or\u00e7ament\u00e1ria, operacional e patrimonial da Uni\u00e3o e das entidades da administra\u00e7\u00e3o direta e indireta, quanto \u00e0 legalidade, legitimidade e economicidade e \u00e0 aplica\u00e7\u00e3o das subven\u00e7\u00f5es e ren\u00fancias tribut\u00e1rias. Assinar prazo para que o \u00f3rg\u00e3o ou entidade adote as provid\u00eancias necess\u00e1rias ao exato cumprimento da lei, se verificada ilegalidade."}], "codigo_penal": null, "codigo_processo_penal": null, "clt": null, "codigo_civil": null, "codigo_processo_civil": null, "codigo_direito_consumidor": null, "estatuto_crianca_adolescente": null, "sumula_stj": null, "estatuto_oab": null, "codigo_tributario_nacional": null, "principio_geral_do_direito": null, "outros": []}
# rule_aleatorio {"constituicao_federal": {"lei": null, "conteudo": null}, "codigo_penal": {"lei": null, "conteudo": null}, "codigo_processo_penal": {"lei": null, "conteudo": null}, "clt": {"lei": null, "conteudo": null}, "codigo_civil": {"lei": null, "conteudo": null}, "codigo_processo_civil": {"lei": null, "conteudo": null}, "codigo_direito_consumidor": {"lei": null, "conteudo": null}, "estatuto_crianca_adolescente": {"lei": null, "conteudo": null}, "sumula_stj": {"lei": null, "conteudo": null}, "estatuto_oab": {"lei": null, "conteudo": null}, "codigo_tributario_nacional": {"lei": null, "conteudo": null}, "principio_geral_do_direito": {"lei": null, "conteudo": null}, "outros": [{"lei": "Art. 1\u00ba da Lei n\u00ba 8.429/92", "conteudo": "Atos de improbidade administrativa s\u00f3 podem ser praticados por agente p\u00fablico, servidor ou n\u00e3o."}, {"lei": "Art. 3\u00ba da Lei n\u00ba 8.429/92", "conteudo": "Aplicam-se as disposi\u00e7\u00f5es da lei de improbidade administrativa \u00e0quele que, mesmo n\u00e3o sendo agente p\u00fablico, induza ou concorra para a pr\u00e1tica do ato de improbidade ou dele se beneficie sob qualquer forma direta ou indireta."}, {"lei": "Art. 11, inciso V, da Lei n\u00ba 8.429/92", "conteudo": "Fraude a concurso p\u00fablico que atentaria contra os princ\u00edpios da administra\u00e7\u00e3o p\u00fablica."}]}
# rule_aleatorio {"constituicao_federal": [{"lei": "Art. 37, inciso II, da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "A investidura em cargo ou emprego p\u00fablico depende de aprova\u00e7\u00e3o em concurso p\u00fablico com cl\u00e1usula de aprova\u00e7\u00e3o em todas as fases do concurso."}, {"lei": "Art. 37, inciso XI, da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "Aplica-se aos servidores p\u00fablicos e aos militares de todos os n\u00edveis da Administra\u00e7\u00e3o P\u00fablica o disposto no inciso XIII do art. 37, bem como as disposi\u00e7\u00f5es de leis que concederem ou determinarem remunera\u00e7\u00e3o superior \u00e0 prevista no mesmo inciso."}, {"lei": "Art. 173, \u00a7 1\u00ba, inciso II, da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "No entanto, a lei estabelecer\u00e1 o regime jur\u00eddico e o prazo de dura\u00e7\u00e3o dos contratos, bem como normas sobre responsabilidade civil, administrativa e penal dos seus dirigentes e empregados, para os crimes definidos em lei, quando praticados no exerc\u00edcio das suas fun\u00e7\u00f5es, ou quando de sua inobserv\u00e2ncia resultar preju\u00edzo para a Fazenda P\u00fablica."}], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"lei": "Posicionamento do STF", "conteudo": "O STF j\u00e1 definiu que \u00e9 obrigat\u00f3ria a motiva\u00e7\u00e3o da dispensa unilateral de empregado p\u00fablico."}]}
# rule_aleatorio {"constituicao_federal": [{"lei": "Art. 5\u00ba, XLII da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "a pr\u00e1tica do racismo constitui crime inafian\u00e7\u00e1vel e imprescrit\u00edvel, sujeito \u00e0 pena de reclus\u00e3o, nos termos da lei;"}, {"lei": "Art. 5\u00ba, XLIV da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "a lei reprimir\u00e3o qualquer discrimina\u00e7\u00e3o atentat\u00f3ria dos direitos e liberdades fundamentais;"}], "codigo_penal": [{"lei": "Art. 217-A do C\u00f3digo Penal", "conteudo": "Ter conjun\u00e7\u00e3o carnal ou praticar outro ato libidinoso com menor de 14 (catorze) anos:"}, {"lei": "Art. 115 do C\u00f3digo Penal", "conteudo": "S\u00e3o reduzidos de metade os prazos de prescri\u00e7\u00e3o: I - se o criminoso era, ao tempo do crime, menor de 21 (vinte e um) anos, ou maior de 70 (setenta) anos;"}, {"lei": "Art. 111, V do C\u00f3digo Penal", "conteudo": "A prescri\u00e7\u00e3o, antes de transitar em julgado a senten\u00e7a final, come\u00e7a a correr: V - nos crimes contra a dignidade sexual ou que envolvam viol\u00eancia contra a crian\u00e7a e o adolescente, previstos neste C\u00f3digo ou em legisla\u00e7\u00e3o especial, da data em que a v\u00edtima completar 18 (dezoito) anos, salvo se a esse tempo j\u00e1 houver sido proposta a a\u00e7\u00e3o penal."}], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [{"lei": "Art. 2\u00ba, caput, do CP", "conteudo": "Ningu\u00e9m pode ser punido por fato que lei posterior deixa de considerar crime, cessando em virtude dela a execu\u00e7\u00e3o e os efeitos penais da senten\u00e7a condenat\u00f3ria."}], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [{"lei": "Art. 157, \u00a7 3\u00ba do C\u00f3digo Penal", "conteudo": "Subtrair coisa m\u00f3vel alheia, para si ou para outrem, mediante grave amea\u00e7a ou viol\u00eancia a pessoa, ou depois de hav\u00ea-la, por qualquer meio, reduzido \u00e0 impossibilidade de resist\u00eancia; \u00a7 3\u00ba - Se da viol\u00eancia resulta les\u00e3o corporal grave, a pena \u00e9 de reclus\u00e3o, de sete a quinze anos, al\u00e9m da multa; se resulta morte, a reclus\u00e3o \u00e9 de vinte a trinta anos, sem preju\u00edzo da multa."}, {"lei": "Art. 155 do C\u00f3digo Penal", "conteudo": "Subtrair, para si ou para outrem, coisa alheia m\u00f3vel."}, {"lei": "Art. 121, \u00a7 2\u00ba, V do C\u00f3digo Penal", "conteudo": "Matar algu\u00e9m: \u00a7 2\u00ba - Se o homic\u00eddio \u00e9 cometido: V - para assegurar a execu\u00e7\u00e3o, a oculta\u00e7\u00e3o, a impunidade ou vantagem de outro crime:"}], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [{"lei": "Art. 611-A, \u00a7 3\u00ba da CLT", "conteudo": "Se for pactuada norma coletiva que reduza o sal\u00e1rio ou a jornada, a norma deve prever a prote\u00e7\u00e3o dos empregados contra dispensa imotivada durante o prazo de vig\u00eancia do instrumento coletivo."}, {"lei": "Art. 614, \u00a7 3\u00ba da CLT", "conteudo": "N\u00e3o ser\u00e1 permitido estipular dura\u00e7\u00e3o de conven\u00e7\u00e3o coletiva ou acordo coletivo de trabalho superior a dois anos, sendo vedada a ultratividade."}], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"lei": "S\u00famula n\u00ba 364 do TST", "conteudo": "Faz jus ao adicional de periculosidade o empregado exposto permanentemente ou que, de forma intermitente, sujeita-se a condi\u00e7\u00f5es de risco. Indevido, apenas, quando o contato d\u00e1-se de forma eventual, assim considerado o fortuito, ou o que, sendo habitual, d\u00e1-se por tempo extremamente reduzido."}, {"lei": "S\u00famula n\u00ba 191 do TST", "conteudo": "O adicional de periculosidade dos eletricit\u00e1rios dever\u00e1 ser calculado sobre o conjunto de parcelas de natureza salarial. (Alterada no final de 2016: apenas os eletrecit\u00e1rios contratados antes da vig\u00eancia da lei n. 7.369/85 continuam com o adicional de periculosidade calculado sobre a totalidade das parcelas salariais. Para os eletrecit\u00e1rios contratados ap\u00f3s a vig\u00eancia da lei, o adicional de periculosidade ser\u00e1 calculado sobre o sal\u00e1rio base.)"}, {"lei": "S\u00famula n\u00ba 361 do TST", "conteudo": "Ainda que a exposi\u00e7\u00e3o ocorra de forma intermitente, o recebimento do adicional de insalubridade deve ocorrer de forma integral."}, {"lei": "Lei n\u00ba 7.369/85", "conteudo": "Regulamenta a percep\u00e7\u00e3o do adicional de periculosidade para os empregados do setor de energia el\u00e9trica."}]}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [{"lei": "Art. 44, I, do CP", "conteudo": "Tratando-se de crime praticado com viol\u00eancia \u00e0 pessoa, n\u00e3o \u00e9 poss\u00edvel a substitui\u00e7\u00e3o da pena privativa de liberdade por restritiva de direitos."}, {"lei": "Art. 77 do CP", "conteudo": "Suspender a execu\u00e7\u00e3o da pena privativa de liberdade por um determinado per\u00edodo (per\u00edodo de prova), em que ficar\u00e1 sujeito a determinadas condi\u00e7\u00f5es que, se cumpridas, acarretar\u00e3o a extin\u00e7\u00e3o da punibilidade do agente."}], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"lei": "Lei n\u00ba 11.340/2006 (Lei Maria da Penha)", "conteudo": "Configura viol\u00eancia dom\u00e9stica e familiar contra a mulher qualquer a\u00e7\u00e3o ou omiss\u00e3o baseada no g\u00eanero que lhe cause morte, les\u00e3o, sofrimento f\u00edsico, sexual ou psicol\u00f3gico e dano moral ou patrimonial, inclusive em qualquer rela\u00e7\u00e3o \u00edntima de afeto, na qual o agressor conviva ou tenha convivido com a ofendida, independentemente de coabita\u00e7\u00e3o."}, {"lei": "Art. 41 Lei n. 11.340/2006", "conteudo": "O crime ser\u00e1 processado mediante a\u00e7\u00e3o penal p\u00fablica incondicionada."}, {"lei": "Art. 89 da Lei n. 9.099/95", "conteudo": "Prev\u00ea a suspens\u00e3o condicional do processo, que n\u00e3o se aplica aos casos de viol\u00eancia dom\u00e9stica e familiar contra a mulher (Lei Maria da Penha)."}]}
# rule_aleatorio {"constituicao_federal": {}, "codigo_penal": {}, "codigo_processo_penal": {}, "clt": {}, "codigo_civil": {}, "codigo_processo_civil": {}, "codigo_direito_consumidor": {}, "estatuto_crianca_adolescente": {}, "sumula_stj": {}, "estatuto_oab": {"lei": "Art. 55, \u00a7 1\u00ba, do C\u00f3digo de \u00c9tica e Disciplina da OAB/2015", "conteudo": "O processo disciplinar pode ser instaurado de of\u00edcio, quando o conhecimento do fato for obtido por meio de fonte id\u00f4nea ou em virtude de comunica\u00e7\u00e3o da autoridade competente."}, "codigo_tributario_nacional": {}, "principio_geral_do_direito": {}, "outros": [{"lei": "Art. 55, \u00a7 2\u00ba, do C\u00f3digo de \u00c9tica e Disciplina da OAB/2015", "conteudo": "O C\u00f3digo de \u00c9tica e Disciplina da OAB n\u00e3o admite a instaura\u00e7\u00e3o de processo disciplinar com fundamento em den\u00fancia an\u00f4nima."}]}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": {"lei": "Art. 7\u00ba, inciso I, al\u00ednea \"a\", do Estatuto da Advocacia e da OAB", "conteudo": "S\u00e3o direitos do advogado poder ingressar livremente em qualquer tribunal,ida\u00e7\u00e3o, delegacia e reparti\u00e7\u00e3o judicial ou onde estejam em causa direitos seus, de seus constituintes ou de quem lhes fa\u00e7a a defesa, sempre com a observ\u00e2ncia das normas de seguran\u00e7a do local, mas com a ressalva de que a advogada gestante, protegida pela maternidade, tem o direito de n\u00e3o ser submetida a detectores de metais e aparelhos de raios X."}, "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": {"lei": "Art. 7\u00ba, VI, \"d\", do EAOAB", "conteudo": "S\u00e3o direitos do advogado: VI - ingressar livremente, em qualquer recinto onde se encontre ou possa estar cliente, ou onde devam ser produzidas ou apresentadas provas: [...] d) em assembleia ou reuni\u00e3o de que participe ou possa participar seu cliente, desde que munido de procura\u00e7\u00e3o com poderes especiais."}, "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
# ...
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"lei": "Art. 6\u00ba, \u00a7 8\u00ba, da Lei n\u00ba 11.101/2005", "conteudo": "A distribui\u00e7\u00e3o do pedido de fal\u00eancia ou de recupera\u00e7\u00e3o judicial ou a homologa\u00e7\u00e3o de recupera\u00e7\u00e3o extrajudicial previne a jurisdi\u00e7\u00e3o para qualquer outro pedido de fal\u00eancia, de recupera\u00e7\u00e3o judicial ou de homologa\u00e7\u00e3o de recupera\u00e7\u00e3o extrajudicial relativo ao mesmo devedor."}]}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"lei": "Decreto n\u00ba 57.663/66, art. 11", "conteudo": "Quando o sacador tiver inserido a cl\u00e1usula 'n\u00e3o \u00e0 ordem', a letra s\u00f3 \u00e9 transmiss\u00edvel pela forma e com os efeitos de uma cess\u00e3o ordin\u00e1ria de cr\u00e9dito."}, {"lei": "Decreto n\u00ba 57.663/66, art. 31", "conteudo": "O aval deve indicar a pessoa por quem se d\u00e1, mas na falta de indica\u00e7\u00e3o entender-se-\u00e1 ser pelo sacador."}]}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [{"lei": "Art. 515, inciso VIII, do NCPC", "conteudo": "Ser\u00e3o sujeitos \u00e0 homologa\u00e7\u00e3o no Brasil as senten\u00e7as estrangeiras, inclusive arbitrais, que n\u00e3o estejam sujeitas \u00e0 autoriza\u00e7\u00e3o ou aprova\u00e7\u00e3o de \u00f3rg\u00e3o administrativo."}, {"lei": "Art. 21, inciso II, do CPC/2015", "conteudo": "Compete \u00e0 autoridade judici\u00e1ria brasileira processar e julgar as causas intentadas contra a Uni\u00e3o, Estados, Distrito Federal e Munic\u00edpios, bem como contra as respectivas autarquias e sociedades de economia mista."}], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": {"lei": "Art. 876 do CPC", "conteudo": "O credor poder\u00e1 adjudicar o bem penhorado, caso deposite a diferen\u00e7a entre o valor do bem e o montante da d\u00edvida. Essa quantia ficar\u00e1 \u00e0 disposi\u00e7\u00e3o do devedor."}, "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [{"lei": "Art. 119 do CPC/2015", "conteudo": "Pendendo causa entre 2 (duas) ou mais pessoas, o terceiro juridicamente interessado em que a senten\u00e7a seja favor\u00e1vel a uma delas poder\u00e1 intervir no processo para assisti-la."}, {"lei": "Art. 130 do CPC/2015", "conteudo": "O chamamento ao processo \u00e9 admiss\u00edvel nas seguintes hip\u00f3teses: I - do afian\u00e7ado, na a\u00e7\u00e3o em que o fiador for r\u00e9u; II - dos demais fiadores, na a\u00e7\u00e3o proposta contra um ou alguns deles; III - dos demais devedores solid\u00e1rios, quando o credor exigir de um ou de alguns o pagamento da d\u00edvida comum."}, {"lei": "Art. 125, II, do CPC/2015", "conteudo": "A denuncia\u00e7\u00e3o \u00e0 lide \u00e9 admitida a todo aquele que estiver obrigado, pela lei ou pelo contrato, a indenizar, no todo ou em parte, o preju\u00edzo do que perdeu, ou seja, se o denunciante for o r\u00e9u. Ao mesmo tempo, o denunciado pode ser denunciado pelo autor."}], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
# rule_aleatorio {"constituicao_federal": [{"lei": "Art. 71, VI, da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "O Tribunal de Contas da Uni\u00e3o, integrado ao sistema de controle externo, exercer\u00e1 a fiscaliza\u00e7\u00e3o cont\u00e1bil, financeira, or\u00e7ament\u00e1ria, operacional e patrimonial da Uni\u00e3o e das entidades da administra\u00e7\u00e3o direta e indireta, quanto \u00e0 legalidade, legitimidade e economicidade e \u00e0 aplica\u00e7\u00e3o das subven\u00e7\u00f5es e ren\u00fancias tribut\u00e1rias. A aplica\u00e7\u00e3o de quaisquer recursos repassados pela Uni\u00e3o mediante conv\u00eanio, acordo, ajuste ou outros instrumentos cong\u00eaneres, a Estado, ao Distrito Federal ou a Munic\u00edpio."}, {"lei": "Art. 71, IX, da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "O Tribunal de Contas da Uni\u00e3o, integrado ao sistema de controle externo, exercer\u00e1 a fiscaliza\u00e7\u00e3o cont\u00e1bil, financeira, or\u00e7ament\u00e1ria, operacional e patrimonial da Uni\u00e3o e das entidades da administra\u00e7\u00e3o direta e indireta, quanto \u00e0 legalidade, legitimidade e economicidade e \u00e0 aplica\u00e7\u00e3o das subven\u00e7\u00f5es e ren\u00fancias tribut\u00e1rias. Assinar prazo para que o \u00f3rg\u00e3o ou entidade adote as provid\u00eancias necess\u00e1rias ao exato cumprimento da lei, se verificada ilegalidade."}], "codigo_penal": null, "codigo_processo_penal": null, "clt": null, "codigo_civil": null, "codigo_processo_civil": null, "codigo_direito_consumidor": null, "estatuto_crianca_adolescente": null, "sumula_stj": null, "estatuto_oab": null, "codigo_tributario_nacional": null, "principio_geral_do_direito": null, "outros": []}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"lei": "Art. 117, XVI, da Lei n\u00ba 8.112/90", "conteudo": "Ao servidor \u00e9 proibido: XVI - utilizar pessoal ou recursos materiais da reparti\u00e7\u00e3o em servi\u00e7os ou atividades particulares."}, {"lei": "Art. 132, XIII, da Lei n\u00ba 8.112/90", "conteudo": "A demiss\u00e3o ser\u00e1 aplicada nos seguintes casos: XIII - transgress\u00e3o dos incisos IX a XVI do art. 117."}, {"lei": "Art. 129 da Lei n\u00ba 8.112/90", "conteudo": "A pena de advert\u00eancia ser\u00e1 aplicada nas hip\u00f3teses de proibi\u00e7\u00e3o constantes do art. 117, incisos I a VIII e XIX."}, {"lei": "Art. 130 da Lei n\u00ba 8.112/90", "conteudo": "A aplica\u00e7\u00e3o de pena de suspens\u00e3o ter\u00e1 lugar nas hip\u00f3teses de reincid\u00eancia das faltas punidas com advert\u00eancia."}, {"lei": "Art. 131, caput, da Lei n\u00ba 8.112/90", "conteudo": "Apenas as penalidades de advert\u00eancia e de suspens\u00e3o ter\u00e3o seus registros cancelados, ap\u00f3s o decurso de 3 (tr\u00eas) e 5 (cinco) anos de efetivo exerc\u00edcio, respectivamente, se o servidor n\u00e3o houver, nesse per\u00edodo, praticado nova infra\u00e7\u00e3o disciplinar."}]}
# rule_aleatorio {"constituicao_federal": {"lei": null, "conteudo": null}, "codigo_penal": {"lei": null, "conteudo": null}, "codigo_processo_penal": {"lei": null, "conteudo": null}, "clt": {"lei": null, "conteudo": null}, "codigo_civil": {"lei": null, "conteudo": null}, "codigo_processo_civil": {"lei": null, "conteudo": null}, "codigo_direito_consumidor": {"lei": null, "conteudo": null}, "estatuto_crianca_adolescente": {"lei": null, "conteudo": null}, "sumula_stj": {"lei": null, "conteudo": null}, "estatuto_oab": {"lei": null, "conteudo": null}, "codigo_tributario_nacional": {"lei": null, "conteudo": null}, "principio_geral_do_direito": {"lei": null, "conteudo": null}, "outros": [{"lei": "Art. 1\u00ba da Lei n\u00ba 8.429/92", "conteudo": "Atos de improbidade administrativa s\u00f3 podem ser praticados por agente p\u00fablico, servidor ou n\u00e3o."}, {"lei": "Art. 3\u00ba da Lei n\u00ba 8.429/92", "conteudo": "Aplicam-se as disposi\u00e7\u00f5es da lei de improbidade administrativa \u00e0quele que, mesmo n\u00e3o sendo agente p\u00fablico, induza ou concorra para a pr\u00e1tica do ato de improbidade ou dele se beneficie sob qualquer forma direta ou indireta."}, {"lei": "Art. 11, inciso V, da Lei n\u00ba 8.429/92", "conteudo": "Fraude a concurso p\u00fablico que atentaria contra os princ\u00edpios da administra\u00e7\u00e3o p\u00fablica."}]}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [{"lei": "Art. 841, \u00a7 3\u00ba da CLT", "conteudo": "Oferecida a contesta\u00e7\u00e3o, ainda que eletronicamente, o reclamante n\u00e3o poder\u00e1, sem o consentimento do reclamado, desistir da a\u00e7\u00e3o."}], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [{"lei": "Art. 852-A da CLT", "conteudo": "O procedimento sumar\u00edssimo \u00e9 aplic\u00e1vel nas reclama\u00e7\u00f5es trabalhistas que n\u00e3o excedam a dois sal\u00e1rios m\u00ednimos."}, {"lei": "Art. 852-H, \u00a7 2\u00ba, da CLT", "conteudo": "Em procedimento sumar\u00edssimo, cada parte poder\u00e1 indicar, no m\u00e1ximo, duas testemunhas."}, {"lei": "Art. 852-A, par\u00e1grafo \u00fanico da CLT", "conteudo": "Est\u00e3o exclu\u00eddas do procedimento sumar\u00edssimo as demandas em que \u00e9 parte a Administra\u00e7\u00e3o P\u00fablica direta, aut\u00e1rquica e fundacional."}], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
# rule_aleatorio {"constituicao_federal": null, "codigo_penal": null, "codigo_processo_penal": null, "clt": [{"lei": "Art. 879, caput, da CLT", "conteudo": "Estabelece que existem tr\u00eas modalidades de liquida\u00e7\u00e3o: c\u00e1lculos, arbitramento e artigos."}, {"lei": "Art. 879, \u00a72\u00ba, da CLT", "conteudo": "O prazo para a impugna\u00e7\u00e3o da liquida\u00e7\u00e3o da senten\u00e7a passou a ser de 8 dias."}], "codigo_civil": null, "codigo_processo_civil": null, "codigo_direito_consumidor": null, "estatuto_crianca_adolescente": null, "sumula_stj": null, "estatuto_oab": null, "codigo_tributario_nacional": null, "principio_geral_do_direito": null, "outros": null}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": {"lei": "Art. 932 do CPC/2015 (antigo art. 557 do CPC/73)", "conteudo": "O relator poder\u00e1 julgar o recurso monocraticamente."}, "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [{"lei": "Princ\u00edpio da Fungibilidade", "conteudo": "Permite a interposi\u00e7\u00e3o de um recurso por outro, desde que preenchidos os requisitos legais e n\u00e3o haja erro grosseiro."}, {"lei": "Princ\u00edpio da Celeridade Processual", "conteudo": "Visa a dar tramita\u00e7\u00e3o mais r\u00e1pida aos processos, evitando a morosidade judicial."}], "outros": [{"lei": "S\u00famula n\u00ba 435 do TST", "conteudo": "Permite a aplica\u00e7\u00e3o subsidi\u00e1ria do art. 932 do CPC (antigo art. 557 do CPC/73) no \u00e2mbito da Justi\u00e7a do Trabalho, autorizando o julgamento monocr\u00e1tico pelo relator."}, {"lei": "S\u00famula n\u00ba 421 do TST", "conteudo": "Disp\u00f5e que da decis\u00e3o monocr\u00e1tica do relator caber\u00e1 embargos de declara\u00e7\u00e3o, e caso se pretenda efeito modificativo, os embargos dever\u00e3o ser submetidos ao Colegiado, convertidos em agravo."}]}
# rule_aleatorio {"constituicao_federal": [], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"lei": "Lei n\u00ba 12.651/2012, Art. 29, caput e \u00a7 2\u00ba", "conteudo": "O Cadastro Ambiental Rural (CAR) \u00e9 obrigat\u00f3rio para todos os im\u00f3veis rurais do Brasil. O CAR consiste em um registro p\u00fablico eletr\u00f4nico de \u00e2mbito nacional, com a finalidade de integrar as informa\u00e7\u00f5es ambientais das propriedades e posses rurais, compondo base de dados para controle, monitoramento, planejamento ambiental e econ\u00f4mico e combate ao desmatamento. O registro no CAR n\u00e3o \u00e9 considerado t\u00edtulo para fins de reconhecimento do direito de propriedade ou posse."}]}
# rule_aleatorio {"constituicao_federal": [{"lei": "Art. 15, V da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "A Constitui\u00e7\u00e3o Federal de 1988, em seu artigo 15, inciso V, estabelece que a improbidade administrativa \u00e9 causa de suspens\u00e3o dos direitos pol\u00edticos."}, {"lei": "Art. 37, \u00a74\u00ba da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "O artigo 37, \u00a74\u00ba da Constitui\u00e7\u00e3o Federal de 1988, em conjunto com o inciso V do artigo 15, tamb\u00e9m fundamenta a suspens\u00e3o dos direitos pol\u00edticos em casos de improbidade administrativa, prevendo san\u00e7\u00f5es, inclusive a perda da fun\u00e7\u00e3o p\u00fablica e a suspens\u00e3o dos direitos pol\u00edticos."}, {"lei": "Art. 15, I da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "A perda dos direitos pol\u00edticos ocorre, entre outras hip\u00f3teses, pelo cancelamento da naturaliza\u00e7\u00e3o por senten\u00e7a transitada em julgado."}, {"lei": "Art. 15, III da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "A suspens\u00e3o dos direitos pol\u00edticos ocorre, entre outras hip\u00f3teses, pela condena\u00e7\u00e3o criminal transitada em julgado, enquanto durarem seus efeitos."}, {"lei": "Art. 15, II da Constitui\u00e7\u00e3o Federal de 1988", "conteudo": "A suspens\u00e3o dos direitos pol\u00edticos ocorre, entre outras hip\u00f3teses, pela incapacidade civil absoluta."}], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [], "codigo_processo_civil": [], "codigo_direito_consumidor": [], "estatuto_crianca_adolescente": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": []}
