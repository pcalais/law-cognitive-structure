# %%
'''
prompt:
Gere codigo python que se conecta na API do Gemini e submete um prompt.
'''
# Out:
# '\nprompt:\nGere codigo python que se conecta na API do Gemini e submete um prompt.\n'

# %%
pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.8.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-api-python-client in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.174.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.40.3)
# Requirement already satisfied: protobuf in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.6.1)
# Requirement already satisfied: tqdm in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (4.66.1)
# Requirement already satisfied: typing-extensions in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core->google-generativeai) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic->google-generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic->google-generativeai) (2.16.2)
# Requirement already satisfied: colorama in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.73.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: C:\Users\pedro\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import google.generativeai as genai

# Substitua pela sua chave de API
API_KEY = "AIzaSyCXAuCP5LWl4Bk5i-6Ha-EX6NxnU8QxDNY"

model_name = "gemini-2.5-flash"

# Configura a API
genai.configure(api_key=API_KEY)

# Cria o modelo
model = genai.GenerativeModel(model_name)

# Submete o prompt
prompt = "Explique a teoria da relatividade em termos simples"
response = model.generate_content(prompt)

# Exibe a resposta
print(response.text)
# Out:
# A Teoria da Relatividade, criada por Albert Einstein, mudou drasticamente nossa compreensão de como o espaço, o tempo, a massa e a energia funcionam no universo, especialmente quando as coisas se movem muito rápido ou quando a gravidade é muito forte.
#
# Para simplificar, podemos dividi-la em duas partes principais:
#
# ---
#
# ### 1. Relatividade Especial (1905)
#
# Essa parte lida com o universo quando *não* há gravidade (ou quando ela é desprezível). Seus dois pilares são:
#
# *   **1. As leis da física são as mesmas para todos os observadores que não estão acelerando.**
#     *   Imagine que você está em um trem se movendo em linha reta e velocidade constante. Se você jogar uma bola para cima, ela cairá da mesma forma que cairia se você estivesse parado na plataforma. Não há experimento que você possa fazer *dentro* do trem que diga se ele está em movimento ou parado.
#
# *   **2. A velocidade da luz no vácuo é a mesma para todo mundo, não importa o quão rápido você esteja se movendo ou a fonte da luz esteja se movendo.**
#     *   Essa é a parte mais "estranha" e revolucionária. Imagine que você está em uma nave espacial viajando a 99% da velocidade da luz. Se você ligar os faróis da nave, a luz ainda se afastará de você na velocidade da luz completa (aproximadamente 300.000 km/s), e não apenas 1% dela.
#
# **Consequências "malucas" da Relatividade Especial:**
#
# *   **Dilatação do Tempo:** Se você se mover muito rápido, o seu tempo passará mais devagar em comparação com alguém parado.
#     *   *Exemplo:* Se um gêmeo viajar para o espaço em uma nave super-rápida e voltar, ele terá envelhecido menos do que o irmão que ficou na Terra. O tempo para ele literalmente passou mais devagar.
# *   **Contração do Comprimento:** Objetos em movimento muito rápido ficam mais curtos na direção do movimento para um observador parado.
#     *   *Exemplo:* Uma nave espacial que passa por você em altíssima velocidade parecerá mais "achatada" na direção do seu movimento.
# *   **Equivalência Massa-Energia (E=mc²):** Massa e energia são, na verdade, a mesma coisa, só que em formas diferentes. Uma pequena quantidade de massa pode ser convertida em uma quantidade gigantesca de energia.
#     *   *Exemplo:* É o princípio por trás do funcionamento do Sol (que converte massa em energia) e das bombas nucleares.
#
# **A grande ideia por trás da Relatividade Especial é que espaço e tempo não são entidades separadas e absolutas, mas sim entrelaçados em algo que chamamos de "espaço-tempo".**
#
# ---
#
# ### 2. Relatividade Geral (1915)
#
# Essa parte estende a relatividade para incluir a **gravidade**. É uma teoria da gravidade muito diferente da de Isaac Newton.
#
# *   **A Gravidade não é uma "força" que puxa, mas sim uma curvatura do espaço-tempo.**
#     *   *Imagine:* Coloque uma bola de boliche pesada no meio de um trampolim esticado. A bola de boliche (um planeta ou estrela) deforma a superfície do trampolim (o espaço-tempo).
#     *   Agora, se você jogar uma bolinha de gude (outro planeta, um asteroide, ou até mesmo um raio de luz) perto da bola de boliche, ela não vai "bater" na bola nem ser "puxada" por uma força. Em vez disso, ela vai "rolar" pela curvatura criada no trampolim.
#     *   É assim que a Relatividade Geral explica a gravidade: **objetos massivos curvam o espaço-tempo ao seu redor, e outros objetos (inclusive a luz) seguem essas curvas.**
#
# **Consequências e Evidências da Relatividade Geral:**
#
# *   **Luz que se Curva:** A luz de estrelas distantes se curva ao passar perto de objetos massivos como o Sol (isso foi confirmado observando estrelas durante um eclipse solar).
# *   **Buracos Negros:** Preveem a existência de buracos negros, regiões onde a curvatura do espaço-tempo é tão extrema que nem a luz consegue escapar.
# *   **Expansão do Universo:** A teoria sugere que o universo pode estar se expandindo (o que foi confirmado).
# *   **Funcionamento do GPS:** Os satélites de GPS orbitam a Terra em alta velocidade e estão sob uma gravidade ligeiramente diferente da superfície. A Relatividade Geral é essencial para corrigir os relógios dos satélites, caso contrário, seu GPS seria impreciso em quilômetros por dia!
# *   **Ondas Gravitacionais:** Preveem "ondulações" no espaço-tempo causadas por eventos cósmicos violentos (como a colisão de buracos negros), que foram detectadas pela primeira vez em 2015.
#
# ---
#
# **Em resumo:**
#
# A **Relatividade Especial** nos diz que espaço e tempo são relativos e se misturam, e que a velocidade da luz é um limite universal e constante.
# A **Relatividade Geral** nos diz que a gravidade não é uma força, mas a maneira como a massa e a energia *deformam* o tecido do espaço-tempo, e tudo (inclusive a luz) simplesmente segue essas deformações.
#
# Ela mudou a física para sempre e é fundamental para entendermos o universo em larga escala, desde a trajetória dos planetas até o funcionamento dos buracos negros.

# %%
import pandas as pd

# Caminho para o arquivo CSV
caminho_csv = "../data/interim/oab.csv"  

# Lê o CSV em um DataFrame
oab_questions_df = pd.read_csv(caminho_csv)

# Visualiza as primeiras linhas
oab_questions_df.head()
# Out:
#        question_id pdf_filename    prova                materia  \
# 0    oab-1.pdf-001    oab-1.pdf       XV     ÉTICA PROFISSIONAL
# 1  oab-152.pdf-001  oab-152.pdf      XIV          DIREITO CIVIL
# 2   oab-88.pdf-001   oab-88.pdf       II  DIREITO INTERNACIONAL
# 3  oab-181.pdf-001  oab-181.pdf       XV                    ECA
# 4   oab-86.pdf-001   oab-86.pdf  INÉDITA      DIREITO ELEITORAL
#
#                                                 tema  questao  \
# 0                    INCOMPATIBILIDADE E IMPEDIMENTO        1
# 1                              DIREITO DAS SUCESSÕES        1
# 2                      DIREITO INTERNACIONAL PÚBLICO        1
# 3  TUTELA JURISDICIONAL DOS DIREITOS DA CRIANÇA E DO        1
# 4                                DIREITO DE SUFRÁGIO        1
#
#                                            enunciado  \
# 0  Abelardo é magistrado vinculado ao Tribunal de...
# 1  Segundo o Código Civil de 2002, acerca do dire...
# 2  Jogador de futebol de um importante time espan...
# 3  ADOLESCENTE\nO Ministério Público moveu ação c...
# 4  A verificação da idade mínima constitucionalme...
#
#                                                    A  \
# 0  A incompatibilidade com a advocacia persiste m...
# 1  É possível que o filho renuncie à herança do p...
# 2  não é competente, porque o réu é pessoa jurídi...
# 3  Não tem cabimento a medida intentada pelo Mini...
# 4   do protocolo do pedido de registro de candidato.
#
#                                      justificativa_A  \
# 0  Afirmação falsa. Após a aposentadoria do juiz,...
# 1  Alternativa correta. Conforme o art. 1.856 do ...
# 2  Afirmação falsa. Enquadrando-se o caso em uma ...
# 3  Afirmação falsa. O Ministério Público possui l...
# 4  Afirmação falsa. A verificação da idade mínima...
#
#                                                    B  \
# 0  O afastamento temporário do cargo que gera a i...
# 1  Na linha transversal, é permitido o direito de...
# 2  terá competência porque os danos à imagem ocor...
# 3  A causa terá seguimento, visto que cabível açã...
# 4  do julgamento do pedido de registro de candidato.
#
#                                      justificativa_B  \
# 0  Afirmação falsa. A incompatibilidade persiste ...
# 1  Afirmação falsa. Nos termos do art. 1.853 do C...
# 2  Alternativa correta. De acordo com o inciso II...
# 3  Afirmação falsa. O direito à saúde deve ser as...
# 4  Afirmação falsa. A verificação da idade mínima...
#
#                                                    C  \
# 0  A incompatibilidade permanece mesmo que ocorra...
# 1  Em não havendo filhos para exercer o direito d...
# 2  deverá remeter o caso, por carta rogatória, à ...
# 3  A ação civil pública é perfeitamente cabível n...
# 4                                      das eleições.
#
#                                      justificativa_C  \
# 0  Alternativa correta. Conforme o art. 28, §1º, ...
# 1  Afirmação falsa. Conforme o art. 1.852 do CC, ...
# 2  Afirmação falsa. Em primeiro lugar destaca-se ...
# 3  Alternativa correta. O Ministério Público poss...
# 4  Afirmação falsa. Vide comentário à alternativa D.
#
#                                                    D  \
# 0  O afastamento do cargo incompatível permite a ...
# 1  O direito de representação consiste no chamame...
# 2  terá competência porque o autor tem nacionalid...
# 3  Não é cabível ação civil pública na hipótese, ...
# 4                                          da posse.
#
#                                      justificativa_D correct
# 0  Afirmação falsa. Não há qualquer previsão lega...       C
# 1  Afirmação falsa. Não se pode falar em represen...       A
# 2  Afirmação falsa. No caso apresentado, a compet...       B
# 3  Afirmação falsa. É cabível a ação civil públic...       C
# 4  Alternativa correta. Segundo o art. 11, §2º da...       D

# %%
# Caminho para o arquivo
caminho_prompt = "prompts/generate_irac_prompt.txt"

# Lê o conteúdo do arquivo como string
with open(caminho_prompt, "r", encoding="utf-8") as arquivo:
    prompt_text = arquivo.read()

# Exibe parte do conteúdo
print(prompt_text)  # Mostra os primeiros 500 caracteres
# Out:
# A partir da questão da OAB e da resolução comentada a seguir, extraia do problema jurídico a estrutura IRAC (Issue, Rule, Application, Conclusion).
#
# Em "Rule", liste todas as doutrinas, princípios, leis e dispositivos constitucionais citados na resolução comentada. Não mencione nenhuma alternativa da questão explicitamente.
#
# A saída deve ser em formato JSON com as chaves "Issue", "Rule", "Application" e "Conclusion".
#
# A chave "Rule" deve ter sub-chaves: "constituicao_federal", "codigo_penal", "codigo_processo_penal", "clt", "codigo_civil", "codigo_processo_civil", "codigo_direito_consumidor", "estatuto_crianca_adolescente", "sumula_stj", "estatuto_oab", "codigo_tributario_nacional", "principio_geral_do_direito" e "outros".
#
# Para cada uma dessas sub-chaves, adicione a chave "lei", com o número, parágrafo, artigo ou inciso da lei, exemplo, "Art. 194 da Constituição Federal de 1988", e uma chave "conteudo", com o conteúdo da lei que a resolução comentada por ventura detalhe, como ""A seguridade social compreende um conjunto integrado de ações de iniciativa dos Poderes Públicos e da sociedade, destinadas a assegurar os direitos relativos à saúde, à previdência e à assistência social.".

# %%
import json

# Função recursiva para coletar todas as ocorrências da chave "lei"
def encontrar_todas_leis(json_string):
    dados = json.loads(json_string)
    leis_encontradas = []

    for categoria in dados.values():
        if categoria == None:
            continue
        for item in categoria:
            if isinstance(item, dict) and "lei" in item:
                leis_encontradas.append(item["lei"])

    return leis_encontradas


rule = """
{"constituicao_federal": [{"lei": "lei tal da CF"}], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [{"lei": "Art. 733 do C\u00f3digo Civil", "conteudo": "Nos contratos de transporte cumulativo, cada transportador se obriga a cumprir o contrato relativamente ao respectivo percurso, respondendo pelos danos nele causados a pessoas e coisas."}], "codigo_processo_civil": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"lei": "Art. 2\u00ba da Lei n\u00ba 9.611/98", "conteudo": "Transporte Multimodal de Cargas \u00e9 aquele que, regido por um \u00fanico contrato, utiliza duas ou mais modalidades de transporte, desde a origem at\u00e9 o destino."}, {"lei": "Conceito de Contrato de Transporte Combinado", "conteudo": "No contrato de transporte combinado o transportador assume a obriga\u00e7\u00e3o de transportar a coisa no seu trecho, assumindo, perante o cliente, a obriga\u00e7\u00e3o de contratar terceiros para a continua\u00e7\u00e3o do transporte em outros trechos."}, {"lei": "Conceito de Transporte de Fato", "conteudo": "O transporte de fato se d\u00e1 quando realizado por pessoa distinta do transportador constante do contrato, autorizado por este a efetuar o transporte integral ou parcialmente."}]}
"""
assert len(encontrar_todas_leis(rule)) == 5
assert len(encontrar_todas_leis("{}")) == 0
assert len(encontrar_todas_leis("""{"constituicao_federal": null, "codigo_penal": null}""")) == 0

# %%
import pandas as pd
import time
from tqdm import tqdm
import os
import json

def create_irac(oab_questions_df, model_name, N, output_path, questions):
    assert oab_questions_df['question_id'].is_unique
    total_questions = len(oab_questions_df)

    # Carrega resultados anteriores, se existirem
    if os.path.exists(output_path):
        existing_df = pd.read_csv(output_path)
        processed_keys = set(existing_df['question_id'])
    else:
        existing_df = pd.DataFrame()
        processed_keys = set()

    remaining_df = oab_questions_df[~oab_questions_df['question_id'].isin(processed_keys)]
    assert remaining_df['question_id'].is_unique

    # Estatísticas de progresso
    total_processed = len(processed_keys)
    total_remaining = len(remaining_df)
    pct_processed = (total_processed / total_questions) * 100
    pct_remaining = (total_remaining / total_questions) * 100

    print(f"Total de questões: {total_questions}")
    print(f"Já processadas: {total_processed} ({pct_processed:.1f}%)")
    print(f"Faltando: {total_remaining} ({pct_remaining:.1f}%)")

    # Se não há mais registros, retorna o DataFrame completo
    if remaining_df.empty:
        print("Todas as questões já foram processadas.")
        return existing_df

    # Seleciona N registros ainda não processados
    amostra_df = remaining_df.sample(n=min(N, total_remaining), random_state=1, replace=False).reset_index(drop=True)

    # Inicializa modelo
    genai.configure(api_key=API_KEY)
    model = genai.GenerativeModel(model_name)

    new_answers_df = pd.DataFrame()

    for index, row in tqdm(amostra_df.iterrows(), total=len(amostra_df), desc=f"Executando questões {model_name}"):
        question_body = f'''
        {row['enunciado']}

        A) {row['A']}.Gabarito comentado: {row['justificativa_A']}
        B) {row['B']} Gabarito comentado: {row['justificativa_B']}
        C) {row['C']} Gabarito comentado: {row['justificativa_C']}
        D) {row['D']} Gabarito comentado: {row['justificativa_D']}
        '''

        response = model.generate_content(prompt_text + "\n" + question_body)
        resposta_texto = response.text

        # Tenta fazer parsing do JSON da resposta
        try:
            irac = json.loads(resposta_texto.replace("```json", "").replace("```", ""))
            issue = irac.get("Issue", "")
            rule = irac.get("Rule", {})
            application = irac.get("Application", "")
            conclusion = irac.get("Conclusion", "")

        except Exception as e:
            print(f"[Erro no parsing JSON] questão {row['questao']}: {e}", resposta_texto)
            print("Skipping...")
            continue
            issue = rule = application = conclusion = ""
            rule = "{}"
            rule_count = 0



        #if row['question_id'] not in questions:
        #    continue

        new_answers_df = pd.concat([
            new_answers_df,
            pd.DataFrame([{
                "question_id": row['question_id'],
                "pdf_filename": row['pdf_filename'],
                "materia": row['materia'],
                "prova": row['prova'],
                "questao": row['questao'],
                "enunciado": row['enunciado'],
                "A": row['A'],
                "justificativa_A": row['justificativa_A'],
                "B": row['B'],
                "justificativa_B": row['justificativa_B'],
                "C": row['C'],
                "justificativa_C": row['justificativa_C'],
                "D": row['D'],
                "justificativa_D": row['justificativa_D'],
                "Issue": issue,
                "Rule": json.dumps(rule),
                "Application": application,
                "Conclusion": conclusion,
                "correct": row['correct'],
                "rule_count": len(encontrar_todas_leis(json.dumps(rule)))
            }])
        ], ignore_index=True)

        assert new_answers_df['question_id'].is_unique

        time.sleep(5)

    # Salva resultados atualizados
    updated_df = pd.concat([existing_df, new_answers_df], ignore_index=True)
    assert updated_df['question_id'].is_unique
    return updated_df

# %%
# https://ai.google.dev/gemini-api/docs/rate-limits
N = 30
caminho_csv = "../data/interim/oab.csv"  
output_path = "../data/processed/oab_with_irac.csv"
oab_questions_df = pd.read_csv(caminho_csv)

oab_with_irac_df = create_irac(oab_questions_df, "gemini-2.5-flash", N, output_path, ["oab-151.pdf-077"])
oab_with_irac_df.to_csv(output_path, index=False, encoding='utf-8-sig')
# Out:
# Total de questões: 3231
# Já processadas: 170 (5.3%)
# Faltando: 3061 (94.7%)
# Executando questões gemini-2.5-flash: 100%|██████████| 30/30 [09:56<00:00, 19.89s/it]

# %%
oab_with_irac_df.shape
# Out:
# (100, 20)

# %%
import pandas as pd
import json
import random

# Carrega o DataFrame
oab_with_irac_df = pd.read_csv("../data/processed/oab_with_irac.csv")

dataframes_por_linha = []
num_linhas = len(oab_with_irac_df)
indices = list(range(num_linhas))

for idx, row in oab_with_irac_df.iterrows():
    nova_linha = row.copy()

    # Extrai "lei" da linha atual para a coluna A
    rule_data = row['Rule']
    leis_A = encontrar_todas_leis(rule_data)
    nova_linha['A'] = '; '.join(str(lei) for lei in leis_A) if leis_A else ''

    # Filtra índices com a mesma matéria (exceto o atual)
    materia_atual = row['materia']
    mesma_materia_indices = oab_with_irac_df[
        (oab_with_irac_df['materia'] == materia_atual) & (oab_with_irac_df.index != idx)
    ].index.tolist()


    # Se houver ao menos 3, usa eles; senão, usa quaisquer outros
    if len(mesma_materia_indices) >= 3:
        aleatorios = random.sample(mesma_materia_indices, 3)
    else:
        possiveis_indices = [i for i in indices if i != idx]
        aleatorios = random.sample(possiveis_indices, 3)

    # Preenche colunas B, C e D
    for col, i_aleatorio in zip(['B', 'C', 'D'], aleatorios):
        rule_aleatorio = oab_with_irac_df.loc[i_aleatorio, 'Rule']
        leis_aleatorias = encontrar_todas_leis(rule_aleatorio)
        valor_concat = '; '.join(str(lei) for lei in leis_aleatorias) if leis_aleatorias else ''
        nova_linha[col] = valor_concat

    df_novo = pd.DataFrame([nova_linha])
    dataframes_por_linha.append(df_novo)

# Junta tudo e salva
df_testa_lei = pd.concat(dataframes_por_linha, ignore_index=True)
df_testa_lei['correct'] = 'A'
df_testa_lei.to_csv("../data/processed/oab_guess_the_rule.csv", index=False, encoding='utf-8-sig')
