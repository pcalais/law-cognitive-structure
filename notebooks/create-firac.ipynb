# %%
'''
prompt:
Gere codigo python que se conecta na API do Gemini e submete um prompt.
'''
# Out:
# '\nprompt:\nGere codigo python que se conecta na API do Gemini e submete um prompt.\n'

# %%
pip install google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: google-generativeai in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.8.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-api-python-client in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.174.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.40.3)
# Requirement already satisfied: protobuf in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.6.1)
# Requirement already satisfied: tqdm in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (4.66.1)
# Requirement already satisfied: typing-extensions in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core->google-generativeai) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic->google-generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic->google-generativeai) (2.16.2)
# Requirement already satisfied: colorama in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.73.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pedro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2023.7.22)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\pedro\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import google.generativeai as genai

with open("api_key.txt", "r") as f:
    API_KEY = f.read().strip().split("\n")[0]

model_name = "gemini-2.5-flash"

# Configura a API
genai.configure(api_key=API_KEY)
print(API_KEY)

# Cria o modelo
model = genai.GenerativeModel(model_name)

# Submete o prompt
prompt = "Explique a teoria da relatividade em termos simples"
response = model.generate_content(prompt)

# Exibe a resposta
print(response.text)
# Out:
# AIzaSyCVyKrp28VP4fQIW-mI2miz7Lw6gBGlRxY
# A Teoria da Relatividade, desenvolvida por Albert Einstein, é uma das ideias mais revolucionárias da ciência. Em termos muito simples, ela nos diz que **o tempo e o espaço não são fixos e absolutos, mas sim relativos e interligados, moldados pela velocidade e pela gravidade.**
#
# Ela é dividida em duas partes principais:
#
# ---
#
# ### 1. Relatividade Especial (1905)
#
# Esta parte lida com a relação entre espaço e tempo para objetos que se movem a **velocidade constante** (sem acelerar) um em relação ao outro.
#
# **As duas ideias centrais são:**
#
# 1.  **A velocidade da luz é a mesma para todos, sempre.** Não importa se você está parado ou correndo em direção a um feixe de luz, a luz sempre viajará a cerca de 300.000 quilômetros por segundo em relação a você. Parece estranho, né? Se você jogar uma bola de um carro em movimento, a velocidade da bola para alguém parado é a velocidade do carro mais a velocidade da bola. Com a luz, isso não acontece.
# 2.  **As leis da física são as mesmas para todos os observadores em movimento constante.** Se você está em um trem se movendo suavemente e não consegue ver para fora, você não consegue dizer se está se movendo ou parado sem olhar para fora. As leis da física funcionam da mesma forma dentro do trem.
#
# **As consequências "loucas" dessas ideias:**
#
# *   **Dilatação do Tempo:** O tempo passa mais devagar para quem está se movendo rápido em relação a você. Se você voasse em uma nave espacial super-rápida, um relógio em seu pulso andaria mais devagar do que um relógio na Terra. Quando você voltasse, teria envelhecido menos do que as pessoas na Terra!
# *   **Contração do Comprimento:** Objetos em movimento rápido parecem encurtar na direção do movimento, vistos por um observador parado.
# *   **Equivalência Massa-Energia (E=mc²):** Massa e energia são duas faces da mesma moeda. Uma pequena quantidade de massa pode ser convertida em uma quantidade enorme de energia (como acontece no Sol ou em bombas nucleares). O "c²" (velocidade da luz ao quadrado) é um número gigantesco, o que significa que mesmo uma massa pequena produz muita energia.
#
# ---
#
# ### 2. Relatividade Geral (1915)
#
# Esta parte expande a Relatividade Especial e incorpora a **gravidade e a aceleração**.
#
# **A ideia central é:**
#
# *   **A gravidade não é uma "força" que puxa as coisas, mas sim a curvatura do espaço-tempo.**
#     *   **Imagine o espaço-tempo como um tecido elástico gigante.** Quando você coloca um objeto pesado (como uma bola de boliche) nesse tecido, ele cria uma depressão, uma curva.
#     *   Objetos menores (como bolinhas de gude) que rolam perto da bola de boliche não são "puxados" por ela. Em vez disso, eles seguem a curva do tecido, parecendo que estão sendo atraídos.
#     *   É exatamente isso que a massa e a energia fazem com o espaço-tempo: elas o distorcem. O que chamamos de "gravidade" é a maneira como os objetos (e a luz) se movem seguindo essas curvas no espaço-tempo.
#
# **As consequências dessa ideia:**
#
# *   **A luz se curva perto de objetos massivos:** Assim como as bolinhas de gude seguem a curva do tecido, a luz também segue as curvas do espaço-tempo. Isso foi comprovado observando a luz de estrelas distantes se curvar ao passar perto do Sol.
# *   **Tempo em gravidade:** O tempo também é afetado pela gravidade. Em locais com gravidade mais forte (mais perto de um planeta grande, por exemplo), o tempo passa mais devagar do que em locais com gravidade mais fraca. Isso é crucial para o funcionamento de sistemas de GPS!
# *   **Buracos Negros:** São regiões onde a gravidade é tão intensa (o espaço-tempo está tão curvado) que nada, nem mesmo a luz, pode escapar.
# *   **Expansão do Universo:** A Relatividade Geral também prevê que o universo como um todo está em expansão.
#
# ---
#
# **Em resumo:**
#
# *   **Relatividade Especial:** Ensina que espaço e tempo são relativos à sua velocidade e que a velocidade da luz é a constante suprema.
# *   **Relatividade Geral:** Ensina que a gravidade não é uma força, mas a curvatura do próprio espaço-tempo, causada pela presença de massa e energia.
#
# A Teoria da Relatividade mudou completamente nossa compreensão do universo, do espaço, do tempo e da gravidade, revelando um cosmos muito mais dinâmico e interconectado do que se imaginava antes de Einstein.

# %%
import pandas as pd

# Caminho para o arquivo CSV
caminho_csv = "../data/interim/oab.csv"  

# Lê o CSV em um DataFrame
oab_questions_df = pd.read_csv(caminho_csv)

# Visualiza as primeiras linhas
oab_questions_df.head()
# Out:
#        question_id pdf_filename    prova                materia  \
# 0    oab-1.pdf-001    oab-1.pdf       XV     ÉTICA PROFISSIONAL
# 1  oab-152.pdf-001  oab-152.pdf      XIV          DIREITO CIVIL
# 2   oab-88.pdf-001   oab-88.pdf       II  DIREITO INTERNACIONAL
# 3  oab-181.pdf-001  oab-181.pdf       XV                    ECA
# 4   oab-86.pdf-001   oab-86.pdf  INÉDITA      DIREITO ELEITORAL
#
#                                                 tema  questao  \
# 0                    INCOMPATIBILIDADE E IMPEDIMENTO        1
# 1                              DIREITO DAS SUCESSÕES        1
# 2                      DIREITO INTERNACIONAL PÚBLICO        1
# 3  TUTELA JURISDICIONAL DOS DIREITOS DA CRIANÇA E DO        1
# 4                                DIREITO DE SUFRÁGIO        1
#
#                                            enunciado  \
# 0  Abelardo é magistrado vinculado ao Tribunal de...
# 1  Segundo o Código Civil de 2002, acerca do dire...
# 2  Jogador de futebol de um importante time espan...
# 3  ADOLESCENTE\nO Ministério Público moveu ação c...
# 4  A verificação da idade mínima constitucionalme...
#
#                                                    A  \
# 0  A incompatibilidade com a advocacia persiste m...
# 1  É possível que o filho renuncie à herança do p...
# 2  não é competente, porque o réu é pessoa jurídi...
# 3  Não tem cabimento a medida intentada pelo Mini...
# 4   do protocolo do pedido de registro de candidato.
#
#                                      justificativa_A  \
# 0  Afirmação falsa. Após a aposentadoria do juiz,...
# 1  Alternativa correta. Conforme o art. 1.856 do ...
# 2  Afirmação falsa. Enquadrando-se o caso em uma ...
# 3  Afirmação falsa. O Ministério Público possui l...
# 4  Afirmação falsa. A verificação da idade mínima...
#
#                                                    B  \
# 0  O afastamento temporário do cargo que gera a i...
# 1  Na linha transversal, é permitido o direito de...
# 2  terá competência porque os danos à imagem ocor...
# 3  A causa terá seguimento, visto que cabível açã...
# 4  do julgamento do pedido de registro de candidato.
#
#                                      justificativa_B  \
# 0  Afirmação falsa. A incompatibilidade persiste ...
# 1  Afirmação falsa. Nos termos do art. 1.853 do C...
# 2  Alternativa correta. De acordo com o inciso II...
# 3  Afirmação falsa. O direito à saúde deve ser as...
# 4  Afirmação falsa. A verificação da idade mínima...
#
#                                                    C  \
# 0  A incompatibilidade permanece mesmo que ocorra...
# 1  Em não havendo filhos para exercer o direito d...
# 2  deverá remeter o caso, por carta rogatória, à ...
# 3  A ação civil pública é perfeitamente cabível n...
# 4                                      das eleições.
#
#                                      justificativa_C  \
# 0  Alternativa correta. Conforme o art. 28, §1º, ...
# 1  Afirmação falsa. Conforme o art. 1.852 do CC, ...
# 2  Afirmação falsa. Em primeiro lugar destaca-se ...
# 3  Alternativa correta. O Ministério Público poss...
# 4  Afirmação falsa. Vide comentário à alternativa D.
#
#                                                    D  \
# 0  O afastamento do cargo incompatível permite a ...
# 1  O direito de representação consiste no chamame...
# 2  terá competência porque o autor tem nacionalid...
# 3  Não é cabível ação civil pública na hipótese, ...
# 4                                          da posse.
#
#                                      justificativa_D correct
# 0  Afirmação falsa. Não há qualquer previsão lega...       C
# 1  Afirmação falsa. Não se pode falar em represen...       A
# 2  Afirmação falsa. No caso apresentado, a compet...       B
# 3  Afirmação falsa. É cabível a ação civil públic...       C
# 4  Alternativa correta. Segundo o art. 11, §2º da...       D

# %%
# Caminho para o arquivo
caminho_prompt = "prompts/generate_firac_prompt.txt"

# Lê o conteúdo do arquivo como string
with open(caminho_prompt, "r", encoding="utf-8") as arquivo:
    prompt_text = arquivo.read()

# Exibe parte do conteúdo
print(prompt_text)  # Mostra os primeiros 500 caracteres
# Out:
# A partir da questão da OAB e da resolução comentada a seguir, extraia do problema jurídico a estrutura FIRAC (Facts, Issue, Rule, Application, Conclusion).
# Restrinja-se apenas ao que é mencionado a resolução comentada, mas não mencione a resolução comentada diretamente.
# A saída deve ser em formato JSON com as chaves "Facts", "Issue", "Rule", "Application" e "Conclusion".
#
# - Facts (Fatos): Identificação detalhada dos eventos relevantes que geraram a disputa jurídica. Gere uma lista de fatos a partir do que é mencionado no enunciado da questão. Deve ser uma lista ([]).
# - Issue (Problema Jurídico): Formulação precisa da questão jurídica central a ser analisada e resolvida.
# - Rule (Direito Aplicável): Seleção das normas jurídicas pertinentes ao problema.
#
# Liste todas as leis e dispositivos constitucionais citados na resolução comentada. Não mencione nenhuma alternativa da questão explicitamente.
#
# A chave "Rule" deve ter os seguintes campos, que representam fontes do Direito: "constituicao_federal", "codigo_penal", "codigo_processo_penal", "clt", "codigo_civil", "codigo_processo_civil", "codigo_direito_consumidor", "estatuto_crianca_adolescente", "sumula_stj", "estatuto_oab", "codigo_etica_disciplina_oab","codigo_tributario_nacional", "lei_federal" e "doutrina".
#
# Para cada uma dessas fontes, o JSON deve ter uma lista de leis mencionadas na resolução comentada.
# Mencione cada lei apenas uma vez. Não inclua conceitos jurídicos abstratos, apenas leis específicas.
# Cada lei deve ser um dicionário com os campos "numero" e "conteúdo". Por exemplo,
#
# [
#     {
#       "numero": "Art. 356 do Código Civil",
#       "conteudo": "O credor pode consentir em receber prestação diversa da que lhe é devida."
#     },
#     {
#       "numero": "Arts. 252 a 256 do Código Civil",
#       "conteudo": "Regulamentam as obrigações alternativas, que se caracterizam por uma única obrigação com pluralidade de prestações, ficando o devedor desobrigado com o adimplemento de qualquer uma delas."
#     }
# ]
#
# - Application (Aplicação da Norma): Confronto das normas jurídicas com os fatos para justificar a solução. Não mencione nenhuma alternativa da questão explicitamente.
# - Conclusion (Conclusão): Definição da solução jurídica proposta com base na análise de todos os itens anteriores. Não mencione nenhuma alternativa da questão explicitamente.

# %%
import json

# Função recursiva para coletar todas as ocorrências da chave "lei"
def encontrar_todas_leis(json_string):
    dados = json.loads(json_string)
    leis_encontradas = []

    for categoria in dados.values():
        if categoria == None:
            continue
        for item in categoria:
            if isinstance(item, dict) and "numero" in item:
                leis_encontradas.append(item["numero"])

    return leis_encontradas


rule = """
{"constituicao_federal": [{"numero": "lei tal da CF"}], "codigo_penal": [], "codigo_processo_penal": [], "clt": [], "codigo_civil": [{"numero": "Art. 733 do C\u00f3digo Civil", "conteudo": "Nos contratos de transporte cumulativo, cada transportador se obriga a cumprir o contrato relativamente ao respectivo percurso, respondendo pelos danos nele causados a pessoas e coisas."}], "codigo_processo_civil": [], "sumula_stj": [], "estatuto_oab": [], "codigo_tributario_nacional": [], "principio_geral_do_direito": [], "outros": [{"numero": "Art. 2\u00ba da Lei n\u00ba 9.611/98", "conteudo": "Transporte Multimodal de Cargas \u00e9 aquele que, regido por um \u00fanico contrato, utiliza duas ou mais modalidades de transporte, desde a origem at\u00e9 o destino."}, {"numero": "Conceito de Contrato de Transporte Combinado", "conteudo": "No contrato de transporte combinado o transportador assume a obriga\u00e7\u00e3o de transportar a coisa no seu trecho, assumindo, perante o cliente, a obriga\u00e7\u00e3o de contratar terceiros para a continua\u00e7\u00e3o do transporte em outros trechos."}, {"numero": "Conceito de Transporte de Fato", "conteudo": "O transporte de fato se d\u00e1 quando realizado por pessoa distinta do transportador constante do contrato, autorizado por este a efetuar o transporte integral ou parcialmente."}]}
"""
assert len(encontrar_todas_leis(rule)) == 5
assert len(encontrar_todas_leis("{}")) == 0
assert len(encontrar_todas_leis("""{"constituicao_federal": null, "codigo_penal": null}""")) == 0

# %%
import pandas as pd
import time
from tqdm import tqdm
import os
import json

def create_firac(oab_questions_df, model_name, N, output_path, questions=[]):
    assert oab_questions_df['question_id'].is_unique
    total_questions = len(oab_questions_df)

    # Carrega resultados anteriores, se existirem
    if os.path.exists(output_path):
        existing_df = pd.read_csv(output_path)
        processed_keys = set(existing_df['question_id'])
    else:
        existing_df = pd.DataFrame()
        processed_keys = set()

    remaining_df = oab_questions_df[~oab_questions_df['question_id'].isin(processed_keys)]
    assert remaining_df['question_id'].is_unique

    # Estatísticas de progresso
    total_processed = len(processed_keys)
    total_remaining = len(remaining_df)
    pct_processed = (total_processed / total_questions) * 100
    pct_remaining = (total_remaining / total_questions) * 100

    print(f"Total de questões: {total_questions}")
    print(f"Já processadas: {total_processed} ({pct_processed:.1f}%)")
    print(f"Faltando: {total_remaining} ({pct_remaining:.1f}%)")

    # Se não há mais registros, retorna o DataFrame completo
    if remaining_df.empty:
        print("Todas as questões já foram processadas.")
        return existing_df

    # Seleciona N registros com menor enunciado:
    #amostra_df = (
    #remaining_df
    #.assign(length=remaining_df['enunciado'].str.len())
    #.sort_values(by='length', ascending=False)
    #.head(N)
    #.drop(columns=['length'])
    #.reset_index(drop=True)
    #)

    # Seleciona N registros ainda não processados
    amostra_df = remaining_df.sample(n=min(N, total_remaining),  replace=False).reset_index(drop=True)

    # Inicializa modelo
    genai.configure(api_key=API_KEY)
    model = genai.GenerativeModel(model_name)

    new_answers_df = pd.DataFrame()

    for index, row in tqdm(amostra_df.iterrows(), total=len(amostra_df), desc=f"Executando questões {model_name}"):
        print(f"Criando FIRAC da questão {row['question_id']}...")

        question_body = f'''
        {row['enunciado']}

        A) {row['A']}.Gabarito comentado: {row['justificativa_A']}
        B) {row['B']} Gabarito comentado: {row['justificativa_B']}
        C) {row['C']} Gabarito comentado: {row['justificativa_C']}
        D) {row['D']} Gabarito comentado: {row['justificativa_D']}
        '''

        response = model.generate_content(prompt_text + "\n" + question_body)
        resposta_texto = response.text

        # Tenta fazer parsing do JSON da resposta
        try:
            firac = json.loads(resposta_texto.replace("```json", "").replace("```", ""))
            facts = firac.get("Facts", "")
            issue = firac.get("Issue", "")
            rule = firac.get("Rule", {})
            application = firac.get("Application", "")
            conclusion = firac.get("Conclusion", "")

            print('facts', facts)
            print('issue', issue)
            print('rule', rule)
            print('application', application)
            print('conclusion', conclusion)


        except Exception as e:
            print(f"[Erro no parsing JSON] questão {row['questao']}: {e}", resposta_texto)
            print("Skipping...")
            continue
            facts = issue = rule = application = conclusion = ""
            rule = "{}"
            rule_count = 0



        #if row['question_id'] not in questions:
        #    continue

        new_answers_df = pd.concat([
            new_answers_df,
            pd.DataFrame([{
                "question_id": row['question_id'],
                "pdf_filename": row['pdf_filename'],
                "materia": row['materia'],
                "oab_test_id": row['prova'],
                "oab_question_id": row['questao'],
                "language": "Portuguese",
                "enunciado": row['enunciado'],
                "A": row['A'],
                "justificativa_A": row['justificativa_A'],
                "B": row['B'],
                "justificativa_B": row['justificativa_B'],
                "C": row['C'],
                "justificativa_C": row['justificativa_C'],
                "D": row['D'],
                "justificativa_D": row['justificativa_D'],
                "Facts": facts,
                "Issue": issue,
                "Rule": json.dumps(rule),
                "Application": application,
                "Conclusion": conclusion,
                "correct_option": row['correct'],
                "fact_count": len(facts),
                "rule_count": len(encontrar_todas_leis(json.dumps(rule)))
            }])
        ], ignore_index=True)

        assert new_answers_df['question_id'].is_unique

        time.sleep(5)

    # Salva resultados atualizados
    updated_df = pd.concat([existing_df, new_answers_df], ignore_index=True)
    updated_df = updated_df.sort_values(by="question_id").reset_index(drop=True)

    assert updated_df['question_id'].is_unique
    return updated_df

# %%
import pandas as pd
import json
from tqdm import tqdm

def translate_firac(oab_questions_portuguese_df, output_foreign_path, language='', N = 5):
    total_questions = len(oab_questions_portuguese_df)

    # Carrega resultados anteriores, se existirem
    if os.path.exists(output_foreign_path):
        translated_oab_df = pd.read_csv(output_foreign_path)
        processed_keys = set(translated_oab_df['question_id'])
    else:
        translated_oab_df = pd.DataFrame()
        processed_keys = set()

    remaining_df = oab_questions_portuguese_df[~oab_questions_portuguese_df['question_id'].isin(processed_keys)]
    assert remaining_df['question_id'].is_unique
    
    # Se não há mais registros, retorna o DataFrame completo
    if remaining_df.empty:
        print("Todas as questões já foram processadas.")
        return translated_oab_df
    
    # Estatísticas de progresso
    total_processed = len(processed_keys)
    total_remaining = len(remaining_df)
    pct_processed = (total_processed / total_questions) * 100
    pct_remaining = (total_remaining / total_questions) * 100    

    print(f"Total de questões em portugues: {total_questions}")
    print(f"Já processadas em Turco: {total_processed} ({pct_processed:.1f}%)")
    print(f"Faltando: {total_remaining} ({pct_remaining:.1f}%)")

    # Seleciona N registros ainda não processados
    amostra_df = remaining_df.sample(n=min(N, total_remaining), random_state=2, replace=False).reset_index(drop=True)

    for index, row in tqdm(amostra_df.iterrows(), total=len(amostra_df), desc=f"Traduzindo {language}"):
        print(f"Traduzindo questão {row['question_id']}...")

        json_row = json.dumps(row.to_dict(), indent=2, ensure_ascii=False)
        prompt = "Translate the values of the JSON to Turkish and return it. Do not change the Keys:" \
                    + "\n" + str(json_row)
        
        response = model.generate_content(prompt)
        json_response = response.text.strip().removeprefix("```json").removesuffix("```").strip()
        json_response = json.loads(json_response)
        print(json_response)

        json_response['materia'] = row['materia']
        json_response['language'] = 'Turkish'

        translated_oab_df = pd.concat([translated_oab_df, pd.DataFrame([json_response])], ignore_index=True)

    translated_oab_df = translated_oab_df.sort_values(by="question_id").reset_index(drop=True)
    return translated_oab_df

# %%
import pandas as pd

# https://ai.google.dev/gemini-api/docs/rate-limits
N = 10
caminho_csv = "../data/interim/oab.csv"  
oab_questions_df = pd.read_csv(caminho_csv)

oab_questions_df = oab_questions_df[oab_questions_df['question_id'] != 'oab-249.pdf-037']

output_path = "../data/processed/oab_with_firac_portuguese.csv"
oab_with_irac_df = create_firac(oab_questions_df, "gemini-2.5-flash", N, output_path)
oab_with_irac_df.to_csv(output_path, index=False, encoding='utf-8-sig')
# Out:
# Total de questões: 3230
# Já processadas: 3223 (99.8%)
# Faltando: 7 (0.2%)
# Executando questões gemini-2.5-flash:   0%|          | 0/7 [00:00<?, ?it/s]
# Criando FIRAC da questão oab-26.pdf-259...
# facts ['O advogado Nelson celebrou um contrato de prestação de serviços profissionais de advocacia com um cliente.', 'O contrato continha uma cláusula que estipulava a forma de contratação de profissionais para serviços auxiliares, como transporte e cópias de processos.', 'O contrato não tratava expressamente sobre o pagamento de custas e emolumentos.']
# issue É permitido que um contrato de prestação de serviços de advocacia inclua disposições sobre a forma de contratação de profissionais para serviços auxiliares e, na ausência de previsão expressa, quem é o responsável pelo pagamento de custas e emolumentos?
# rule {'constituicao_federal': [], 'codigo_penal': [], 'codigo_processo_penal': [], 'clt': [], 'codigo_civil': [], 'codigo_processo_civil': [], 'codigo_direito_consumidor': [], 'estatuto_crianca_adolescente': [], 'sumula_stj': [], 'estatuto_oab': [], 'codigo_etica_disciplina_oab': [{'numero': 'Art. 48, § 3º do Código de Ética e Disciplina da OAB', 'conteudo': 'O contrato de prestação de serviços poderá dispor sobre a forma de contratação de profissionais para serviços auxiliares, bem como sobre o pagamento de custas e emolumentos, os quais, na ausência de disposição em contrário, presumem-se devam ser atendidos pelo cliente.'}], 'codigo_tributario_nacional': [], 'lei_federal': [], 'doutrina': []}
# application A regulamentação profissional permite que o contrato de prestação de serviços de advocacia contenha previsões sobre a contratação de profissionais para serviços auxiliares. Em relação às custas e aos emolumentos, a mesma regulamentação estabelece que, se o contrato não dispuser de forma contrária, presume-se que tais despesas devem ser pagas pelo cliente. A previsão de que o advogado antecipe essas despesas exige expressa disposição contratual.
# conclusion O contrato de prestação de serviços de advocacia pode incluir disposições sobre a forma de contratação de profissionais para serviços auxiliares. Na ausência de cláusula expressa no contrato sobre o pagamento de custas e emolumentos, a responsabilidade por essas despesas é presumidamente do cliente.
# Executando questões gemini-2.5-flash:  14%|█▍        | 1/7 [00:14<01:28, 14.81s/it]
# Criando FIRAC da questão oab-91.pdf-033...
# facts ['Uma carta rogatória foi encaminhada.', 'A carta rogatória foi encaminhada nos termos da Convenção Interamericana sobre Cartas Rogatórias.', 'O objetivo da carta rogatória é a citação de uma pessoa física.', 'A pessoa física a ser citada está domiciliada em São Paulo, Brasil.', 'A pessoa física deve responder a um processo de divórcio que tramita nos Estados Unidos.']
# issue Qual a competência para a concessão de exequatur e para o cumprimento de uma carta rogatória encaminhada sob os termos de uma convenção internacional, visando à citação de pessoa física domiciliada no Brasil?
# rule {'constituicao_federal': [{'numero': 'Art. 105, inciso I, alínea “i”, da CF/88', 'conteudo': 'a concessão de exequatur às cartas rogatórias é de competência do STJ'}, {'numero': 'Art. 109, inciso X, da CF/88', 'conteudo': 'O cumprimento da carta rogatória é de competência da Justiça Federal'}], 'codigo_penal': [], 'codigo_processo_penal': [], 'clt': [], 'codigo_civil': [], 'codigo_processo_civil': [], 'codigo_direito_consumidor': [], 'estatuto_crianca_adolescente': [], 'sumula_stj': [], 'estatuto_oab': [], 'codigo_etica_disciplina_oab': [], 'codigo_tributario_nacional': [], 'lei_federal': [], 'doutrina': []}
# application Uma carta rogatória encaminhada, mesmo que nos termos de um tratado multilateral como a Convenção Interamericana sobre Cartas Rogatórias, não dispensa a necessidade de exequatur. A competência para a concessão do exequatur é do Superior Tribunal de Justiça. Posteriormente, o cumprimento da ordem de citação, que se refere a uma pessoa física domiciliada no Brasil, é de competência da Justiça Federal.
# conclusion A concessão de exequatur para a carta rogatória compete ao Superior Tribunal de Justiça, e o seu posterior cumprimento compete à Justiça Federal.
# Executando questões gemini-2.5-flash:  29%|██▊       | 2/7 [00:28<01:11, 14.33s/it]
# Criando FIRAC da questão oab-211.pdf-128...
# facts ['A discussão jurídica envolve a cessão de quotas de sociedade empresária limitada.', 'Considera-se a responsabilidade do cedente perante a sociedade e terceiros após a averbação da modificação do contrato social.', 'Analisa-se a possibilidade de um sócio ceder sua quota, total ou parcialmente, a outro sócio na omissão do contrato social.', 'Avalia-se o momento de eficácia da cessão de quotas entre cedente e cessionário, bem como perante a sociedade e terceiros.', 'Examina-se a condição para que um sócio ceda sua quota, total ou parcialmente, para terceiro estranho à sociedade, na ausência de disposição contratual.']
# issue Quais são as regras legais aplicáveis e as condições para a cessão de quotas em uma sociedade empresária limitada, incluindo a responsabilidade do cedente e a eficácia da cessão perante diferentes partes?
# rule {'constituicao_federal': [], 'codigo_penal': [], 'codigo_processo_penal': [], 'clt': [], 'codigo_civil': [{'numero': 'Art. 1.033 do Código Civil', 'conteudo': 'O cedente responde solidariamente com o cessionário, perante a sociedade e terceiros, pelas obrigações que tinha como sócio, até dois anos depois de averbada a modificação do contrato.'}, {'numero': 'Art. 1.053 do Código Civil', 'conteudo': 'Estabelece a aplicabilidade subsidiária das normas da sociedade simples à sociedade limitada, incluindo a regra do Art. 1.033.'}, {'numero': 'Art. 1.057 do Código Civil', 'conteudo': 'Na omissão do contrato, o sócio pode ceder sua quota, total ou parcialmente, a quem seja sócio, independentemente de audiência dos outros. Na omissão do contrato, o sócio pode ceder sua quota, total ou parcialmente, a pessoa estranha à sociedade, se não houver oposição de titulares de mais de um quarto do capital social.'}, {'numero': 'Art. 1.057, parágrafo único, do Código Civil', 'conteudo': 'A cessão só terá eficácia quanto à sociedade e terceiros a partir da averbação do respectivo instrumento, subscrito pelos sócios anuentes.'}], 'codigo_processo_civil': [], 'codigo_direito_consumidor': [], 'estatuto_crianca_adolescente': [], 'sumula_stj': [], 'estatuto_oab': [], 'codigo_etica_disciplina_oab': [], 'codigo_tributario_nacional': [], 'lei_federal': [], 'doutrina': []}
# application A afirmação de que o cedente responde solidariamente com o cessionário por três anos pelas obrigações que tinha como sócio, após a averbação da modificação do contrato social, não está em conformidade com a legislação aplicável. O prazo estabelecido por lei para tal responsabilidade é de dois anos, conforme explicitado pelas normas que regem a matéria e sua aplicação às sociedades limitadas.
#
# Em contraste, a previsão de que, na omissão do contrato social, o sócio pode ceder sua quota, total ou parcialmente, a quem já integra o quadro social, independentemente da audiência dos demais sócios, está em plena conformidade com a literalidade do Código Civil.
#
# Quanto à eficácia da cessão de quotas, a validade entre cedente e cessionário não depende da averbação no registro competente, mas ocorre desde a assinatura do contrato. A averbação é o marco para que a cessão produza efeitos perante a sociedade e terceiros.
#
# Por fim, a condição para a cessão de quotas a um terceiro, estranho à sociedade, quando o contrato social for omisso, não exige a concordância unânime dos demais sócios. A lei prevê que tal cessão é possível desde que não haja oposição de titulares de mais de um quarto do capital social.
# conclusion Em síntese, a regra correta em matéria de cessão de quotas de sociedade limitada é que, na ausência de estipulação contratual, o sócio detém a prerrogativa de ceder sua quota, seja total ou parcialmente, a outro sócio já existente, sem a necessidade de consultar os demais integrantes da sociedade.
# Executando questões gemini-2.5-flash:  43%|████▎     | 3/7 [00:57<01:22, 20.70s/it]
# Criando FIRAC da questão oab-50.pdf-036...
# facts ['José é cidadão do município W.', 'O distrito de B está localizado no município W.', 'José realizou consultas informais e verificou o desejo da população distrital de B em obter a emancipação em relação ao município de origem.']
# issue Quais são os requisitos indispensáveis, de acordo com as normas constitucionais federais, para legitimar a criação de um novo Município, especificamente o desmembramento de um distrito?
# rule {'constituicao_federal': [{'numero': 'Art. 18, §4º, da Constituição Federal', 'conteudo': 'A criação, a incorporação, a fusão e o desmembramento de Municípios, far-se-ão por lei estadual, dentro do período determinado por Lei Complementar Federal, e dependerão de consulta prévia, mediante plebiscito, às populações dos Municípios envolvidos, após divulgação dos Estudos de Viabilidade Municipal, apresentados e publicados na forma da lei.'}], 'codigo_penal': [], 'codigo_processo_penal': [], 'clt': [], 'codigo_civil': [], 'codigo_processo_civil': [], 'codigo_direito_consumidor': [], 'estatuto_crianca_adolescente': [], 'sumula_stj': [], 'estatuto_oab': [], 'codigo_etica_disciplina_oab': [], 'codigo_tributario_nacional': [], 'lei_federal': [{'numero': 'Lei Complementar Federal', 'conteudo': 'Determina o período dentro do qual a criação, incorporação, fusão e desmembramento de Municípios podem ser realizados por lei estadual.'}], 'doutrina': []}
# application Conforme a norma constitucional federal que regula a matéria, o desmembramento de um Município exige a promulgação de uma lei estadual, devendo ocorrer dentro de um período determinado por lei complementar federal. Adicionalmente, é indispensável a realização de consulta prévia à população por meio de plebiscito. A exigência de lei municipal não se coaduna com a norma, que estabelece a necessidade de lei estadual. Da mesma forma, a exigência de referendo não é a correta, pois a norma constitucional prevê expressamente a realização de plebiscito.
# conclusion Para legitimar a criação de um novo Município, proveniente do desmembramento de um distrito, os requisitos indispensáveis são a edição de lei estadual e a realização de plebiscito.
# Executando questões gemini-2.5-flash:  57%|█████▋    | 4/7 [01:10<00:53, 17.86s/it]
# Criando FIRAC da questão oab-316.pdf-197...
# facts ['Carlos foi contratado como estagiário em 2018.', 'A contratação ocorreu por uma indústria automobilística.', 'O contrato de estágio foi estabelecido pelo prazo de dois anos.', 'Todas as exigências legais para o estágio foram atendidas.', 'O estágio era remunerado.', 'Após um ano de vigência do contrato, Carlos buscou orientação jurídica.']
# issue Carlos, na condição de estagiário que completou um ano de contrato, tem direito a um período de recesso remunerado e, em caso afirmativo, se este período incluirá o acréscimo de um terço?
# rule {'constituicao_federal': [], 'codigo_penal': [], 'codigo_processo_penal': [], 'clt': [], 'codigo_civil': [], 'codigo_processo_civil': [], 'codigo_direito_consumidor': [], 'estatuto_crianca_adolescente': [], 'sumula_stj': [], 'estatuto_oab': [], 'codigo_etica_disciplina_oab': [], 'codigo_tributario_nacional': [], 'lei_federal': [{'numero': 'Art. 13 da Lei n. 11.788/2008', 'conteudo': 'Assegura ao estagiário, sempre que o estágio tenha duração igual ou superior a 1 (um) ano, período de recesso de 30 (trinta) dias, a ser gozado preferencialmente durante suas férias escolares.'}], 'doutrina': []}
# application Considerando que Carlos completou um ano de duração do estágio, a legislação aplicável garante a ele um período de recesso de 30 dias. Este recesso é remunerado e deve ser gozado, preferencialmente, durante as férias escolares. Contudo, em virtude da natureza do contrato de estágio, que configura uma relação de trabalho e não uma relação de emprego, não há previsão legal para o acréscimo de um terço sobre o valor devido pelo recesso.
# conclusion Carlos terá direito a um recesso remunerado de 30 dias após completar um ano de estágio, mas sem o acréscimo de um terço.
# Executando questões gemini-2.5-flash:  71%|███████▏  | 5/7 [01:25<00:33, 16.66s/it]
# Criando FIRAC da questão oab-126.pdf-073...
# facts ['Antônio, vítima em um acidente automobilístico, foi atendido em um hospital da rede pública do Município de Mar Azul.', 'Durante o atendimento hospitalar, um médico que o assistiu agiu com imperícia.', 'A imperícia médica resultou na amputação de um terço da perna direita de Antônio.']
# issue Qual a natureza da responsabilidade do Município de Mar Azul e do médico pelos danos causados a Antônio em decorrência da imperícia médica em um hospital público?
# rule {'constituicao_federal': [{'numero': 'Art. 37, §6º, da CF/88', 'conteudo': 'As pessoas jurídicas de direito público e as de direito privado prestadoras de serviços públicos responderão pelos danos que seus agentes, nessa qualidade, causarem a terceiros, assegurado o direito de regresso contra o responsável nos casos de dolo ou culpa.'}], 'codigo_penal': [], 'codigo_processo_penal': [], 'clt': [], 'codigo_civil': [], 'codigo_processo_civil': [], 'codigo_direito_consumidor': [], 'estatuto_crianca_adolescente': [], 'sumula_stj': [], 'estatuto_oab': [], 'codigo_etica_disciplina_oab': [], 'codigo_tributario_nacional': [], 'lei_federal': [], 'doutrina': []}
# application As pessoas jurídicas de direito público, como o Município de Mar Azul, que são prestadoras de serviços públicos, possuem responsabilidade objetiva pelos danos que seus agentes causam a terceiros no exercício de suas funções. No caso em questão, o médico agiu com culpa (imperícia), resultando em dano a Antônio. A lei garante que, para tais situações, o ente público tem o direito de regresso contra o agente responsável, desde que este tenha agido com dolo ou culpa. Assim, a responsabilidade do médico é regressiva e não solidária, objetiva ou subsidiária.
# conclusion O Município de Mar Azul é responsável objetivamente pelo dano causado a Antônio, enquanto o médico, que agiu com culpa, responderá regressivamente.
# Executando questões gemini-2.5-flash:  86%|████████▌ | 6/7 [01:39<00:15, 15.80s/it]
# Criando FIRAC da questão oab-279.pdf-078...
# facts ['A prisão temporária é uma medida cautelar restritiva, decretada por tempo determinado.', 'Ela é destinada a possibilitar as investigações de certos crimes considerados graves pelo legislador.', 'A decretação da prisão temporária ocorre antes da propositura da ação penal.']
# issue Quais são as condições, prazos e procedimentos corretos que regem a decretação e o cumprimento da prisão temporária?
# rule {'constituicao_federal': [], 'codigo_penal': [], 'codigo_processo_penal': [], 'clt': [], 'codigo_civil': [], 'codigo_processo_civil': [], 'codigo_direito_consumidor': [], 'estatuto_crianca_adolescente': [], 'sumula_stj': [], 'estatuto_oab': [], 'codigo_etica_disciplina_oab': [], 'codigo_tributario_nacional': [], 'lei_federal': [{'numero': 'Art. 2º, caput, da Lei nº 7.960/89', 'conteudo': 'A prisão temporária não pode ser decretada de ofício pelo juiz, dependendo de representação da autoridade policial ou de requerimento do Ministério Público.'}, {'numero': 'Art. 2º, § 4º, da Lei nº 8.072/90', 'conteudo': 'A prisão temporária no caso de crimes hediondos terá prazo de 30 dias prorrogável por igual período.'}, {'numero': 'Art. 2º, § 7º, da Lei nº 7.960/89', 'conteudo': 'Decorrido o prazo de cinco dias de detenção, o preso deverá ser posto imediatamente em liberdade, salvo se já tiver sido decretada sua prisão preventiva.'}, {'numero': 'Art. 3º, da Lei nº 7.960/89', 'conteudo': 'Os presos temporários deverão permanecer, obrigatoriamente, separados dos demais detentos.'}], 'doutrina': []}
# application ['A decretação da prisão temporária não pode ser iniciativa exclusiva do juiz, exigindo sempre uma solicitação formal da autoridade policial ou do Ministério Público.', 'Para a investigação de crimes hediondos, o período de prisão temporária é estipulado em 30 dias, admitindo-se uma prorrogação por mais 30 dias.', 'Findando o período de detenção temporária legalmente estabelecido, e na ausência de uma determinação de prisão preventiva, o indivíduo deve ser imediatamente liberado.', 'Aqueles que se encontram sob prisão temporária devem ser mantidos em instalações separadas dos demais tipos de detentos, sejam eles provisórios ou condenados.']
# conclusion O indivíduo detido por prisão temporária deve ser imediatamente libertado ao término do prazo fixado para sua detenção, a menos que uma prisão preventiva já tenha sido decretada.
# Executando questões gemini-2.5-flash: 100%|██████████| 7/7 [01:55<00:00, 16.52s/it]

# %%
1/0

output_path = "../data/processed/oab_with_firac_turkish.csv"

N = 1

oab_with_irac_turkish_df = translate_firac(oab_with_irac_df, output_path, language='Turkish', N=N)

oab_with_irac_turkish_df.to_csv(output_path, index=False, encoding='utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 1/0
#       3 output_path = "../data/processed/oab_with_firac_turkish.csv"
#       5 N = 1
#
# ZeroDivisionError: division by zero

# %%
oab_with_irac_df.shape

# %%
import pandas as pd
import json
import random

# Carrega o DataFrame
oab_with_irac_df = pd.read_csv("../data/processed/oab_with_firac_portuguese.csv")

dataframes_por_linha = []
num_linhas = len(oab_with_irac_df)
indices = list(range(num_linhas))

for idx, row in oab_with_irac_df.iterrows():
    nova_linha = row.copy()

    # Extrai "lei" da linha atual para a coluna A
    rule_data = row['Rule']
    leis_A = encontrar_todas_leis(rule_data)
    nova_linha['A'] = '; '.join(str(lei) for lei in leis_A) if leis_A else ''

    # Filtra índices com a mesma matéria (exceto o atual)
    materia_atual = row['materia']
    mesma_materia_indices = oab_with_irac_df[
        (oab_with_irac_df['materia'] == materia_atual) & (oab_with_irac_df.index != idx)
    ].index.tolist()


    # Se houver ao menos 3, usa eles; senão, usa quaisquer outros
    if len(mesma_materia_indices) >= 3:
        aleatorios = random.sample(mesma_materia_indices, 3)
    else:
        possiveis_indices = [i for i in indices if i != idx]
        aleatorios = random.sample(possiveis_indices, 3)

    # Preenche colunas B, C e D
    for col, i_aleatorio in zip(['B', 'C', 'D'], aleatorios):
        rule_aleatorio = oab_with_irac_df.loc[i_aleatorio, 'Rule']
        leis_aleatorias = encontrar_todas_leis(rule_aleatorio)
        valor_concat = '; '.join(str(lei) for lei in leis_aleatorias) if leis_aleatorias else ''
        nova_linha[col] = valor_concat

    df_novo = pd.DataFrame([nova_linha])
    dataframes_por_linha.append(df_novo)

# Junta tudo e salva
df_testa_lei = pd.concat(dataframes_por_linha, ignore_index=True)
df_testa_lei['correct'] = 'A'
df_testa_lei.to_csv("../data/processed/oab_guess_the_rule.csv", index=False, encoding='utf-8-sig')
