# %%
import pandas as pd

oab_exam_df = pd.read_csv("../data/processed/oab_with_firac_portuguese.csv")


oab_exam_df.head()
# Out:
#      question_id pdf_filename             materia oab_test_id  \
# 0  oab-1.pdf-001    oab-1.pdf  ÉTICA PROFISSIONAL          XV
# 1  oab-1.pdf-002    oab-1.pdf  ÉTICA PROFISSIONAL          XV
# 2  oab-1.pdf-003    oab-1.pdf  ÉTICA PROFISSIONAL          XV
# 3  oab-1.pdf-004    oab-1.pdf  ÉTICA PROFISSIONAL          XV
# 4  oab-1.pdf-005    oab-1.pdf  ÉTICA PROFISSIONAL         XIV
#
#    oab_question_id    language  \
# 0                1  Portuguese
# 1                2  Portuguese
# 2                3  Portuguese
# 3                4  Portuguese
# 4                5  Portuguese
#
#                                            enunciado  \
# 0  Abelardo é magistrado vinculado ao Tribunal de...
# 1  Fred, jovem advogado, é contratado para presta...
# 2  O advogado Caio atuava representando os intere...
# 3  Os advogados X de Souza, Y dos Santos e Z de A...
# 4  Matheus é estagiário vinculado ao escritório R...
#
#                                                    A  \
# 0  A incompatibilidade com a advocacia persiste m...
# 1  deve submeter-se à determinação da gerência ju...
# 2  Tício não pode ajuizar tal ação porque, como C...
# 3  É possível manter o nome do sócio falecido, de...
# 4  O advogado pode afastar-se do processo em que ...
#
#                                      justificativa_A  \
# 0  Afirmação falsa. Após a aposentadoria do juiz,...
# 1  Afirmação falsa. Todo advogado possui liberdad...
# 2  Afirmação falsa. Os honorários são devidos (ar...
# 3  Alternativa correta. Nos termos do art. 16, §1...
# 4  Afirmação falsa. O advogado, ao renunciar o ma...
#
#                                                    B  ...  \
# 0  O afastamento temporário do cargo que gera a i...  ...
# 1  deve apresentar seu parecer ao conjunto de adv...  ...
# 2  Tício pode ajuizar tal ação, pois ingressou na...  ...
# 3  É possível manter o nome do sócio falecido, in...  ...
# 4  A renúncia deve ser notificada ao cliente pelo...  ...
#
#                                                    D  \
# 0  O afastamento do cargo incompatível permite a ...
# 1         pode opor-se e postular assessoria da OAB.
# 2  Tício não pode ajuizar tal ação porque o advog...
# 3  É possível manter, pelo prazo máximo de seis m...
# 4  A renúncia ao mandato, sem respeitar o prazo l...
#
#                                      justificativa_D  \
# 0  Afirmação falsa. Não há qualquer previsão lega...
# 1  Afirmação falsa. Não há previsão legal para qu...
# 2  Alternativa correta. O advogado substabelecido...
# 3  Afirmação falsa. O EAOAB não fixa qualquer pra...
# 4  Afirmação falsa para FGV. A renúncia ao mandat...
#
#                                                Facts  \
# 0  ['Abelardo é magistrado vinculado ao Tribunal ...
# 1  ['Fred, um jovem advogado, foi contratado para...
# 2  ['Um advogado, Caio, representava um cliente e...
# 3  ['Os advogados X de Souza, Y dos Santos e Z de...
# 4  ['Matheus, um estagiário vinculado ao escritór...
#
#                                                Issue  \
# 0  Um magistrado em licença temporária para trata...
# 1  Nos termos do Código de Ética da Advocacia, qu...
# 2  Pode o advogado que recebeu substabelecimento ...
# 3  É juridicamente permitido manter o nome de um ...
# 4  Quais são os requisitos legais e as implicaçõe...
#
#                                                 Rule  \
# 0  {"constituicao_federal": [{"numero": "Art. 95,...
# 1  {"constituicao_federal": [], "codigo_penal": [...
# 2  {"constituicao_federal": [], "codigo_penal": [...
# 3  {"constituicao_federal": [], "codigo_penal": [...
# 4  {"constituicao_federal": [], "codigo_penal": [...
#
#                                          Application  \
# 0  Abelardo é um magistrado que obteve licença pa...
# 1  O advogado possui liberdade e independência no...
# 2  Os honorários advocatícios de êxito são devido...
# 3  A legislação aplicável permite a permanência d...
# 4  Considerando a decisão do escritório de renunc...
#
#                                           Conclusion correct_option  \
# 0  A incompatibilidade para o exercício da advoca...              C
# 1  O advogado pode recusar-se a propor a ação dia...              C
# 2  O advogado que recebeu substabelecimento com r...              D
# 3  É possível manter o nome do sócio falecido na ...              A
# 4  A renúncia do mandato por parte do escritório ...              B
#
#   fact_count rule_count
# 0          5          3
# 1          7          3
# 2          6          4
# 3          4          1
# 4          3          2
#
# [5 rows x 23 columns]

# %%
oab_exam_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3230 entries, 0 to 3229
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   question_id      3230 non-null   object
#  1   pdf_filename     3230 non-null   object
#  2   materia          3230 non-null   object
#  3   oab_test_id      3230 non-null   object
#  4   oab_question_id  3230 non-null   int64
#  5   language         3230 non-null   object
#  6   enunciado        3230 non-null   object
#  7   A                3230 non-null   object
#  8   justificativa_A  3215 non-null   object
#  9   B                3229 non-null   object
#  10  justificativa_B  3216 non-null   object
#  11  C                3230 non-null   object
#  12  justificativa_C  3222 non-null   object
#  13  D                3230 non-null   object
#  14  justificativa_D  3226 non-null   object
#  15  Facts            3230 non-null   object
#  16  Issue            3230 non-null   object
#  17  Rule             3230 non-null   object
#  18  Application      3229 non-null   object
#  19  Conclusion       3222 non-null   object
#  20  correct_option   3230 non-null   object
#  21  fact_count       3230 non-null   int64
#  22  rule_count       3230 non-null   int64
# dtypes: int64(3), object(20)
# memory usage: 580.5+ KB

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define os bins com passo 1
bins = np.arange(oab_exam_df['fact_count'].min(), 
                 oab_exam_df['fact_count'].max() + 2) - 0.5  # centraliza nos inteiros

plt.figure(figsize=(8, 5))
plt.hist(oab_exam_df['fact_count'], bins=bins, edgecolor='black')
plt.xlabel('Número de Fatos (fact_count)')
plt.ylabel('Frequência')
plt.title('Histograma da Coluna fact_count (bin size = 1)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define os bins com passo 1
bins = np.arange(oab_exam_df['rule_count'].min(), 
                 oab_exam_df['rule_count'].max() + 2) - 0.5  # centraliza nos inteiros

plt.figure(figsize=(8, 5))
plt.hist(oab_exam_df['rule_count'], bins=bins, edgecolor='black')
plt.xlabel('Número de Regras (rule_count)')
plt.ylabel('Frequência')
plt.title('Histograma da Coluna rule_count (bin size = 1)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Calcula a correlação de Pearson entre fact_count e rule_count
pearson_corr = oab_exam_df['fact_count'].corr(oab_exam_df['rule_count'], method='pearson')

print(f"Correlação de Pearson entre fact_count e rule_count: {pearson_corr:.3f}")
# Out:
# Correlação de Pearson entre fact_count e rule_count: -0.091

# %%
import matplotlib.pyplot as plt

# Conta a frequência de cada matéria
materia_counts = oab_exam_df['materia'].value_counts()

# Cria o gráfico de barras horizontal
plt.figure(figsize=(10, 6))
plt.barh(materia_counts.index, materia_counts.values)
plt.xlabel('Número de Questões')
plt.ylabel('Matéria')
plt.title('Distribuição de Questões por Matéria (Exame OAB)')
plt.gca().invert_yaxis()  # opcional: coloca a matéria mais frequente no topo
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import json
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# 1. Converte a coluna Rule para dicionário (se ainda não estiver)
oab_exam_df['Rule_dict'] = oab_exam_df['Rule'].apply(
    lambda x: json.loads(x) if isinstance(x, str) else x
)

# 2. Extrai automaticamente todas as chaves (tipos de lei) encontradas nos JSONs
all_keys = sorted({
    key
    for d in oab_exam_df['Rule_dict']
    for key in d.keys()
})

# 3. Cria colunas com a contagem de itens em cada tipo de lei
for law in all_keys:
    oab_exam_df[law] = oab_exam_df['Rule_dict'].apply(lambda x: len(x.get(law, [])))

# 4. Calcula a média de leis por tipo, agrupando por 'materia'
avg_laws = oab_exam_df.groupby('materia')[all_keys].mean().round(2)

# 5. Cria uma máscara onde o valor é 0
mask = avg_laws == 0

# 6. Plota o heatmap com as células 0 ocultas (em branco)
plt.figure(figsize=(12, 6))
sns.heatmap(
    avg_laws,
    annot=True,
    cmap='Blues',
    fmt=".2f",
    cbar=True,
    linewidths=0.5,
    linecolor='white',
    mask=mask
)
plt.title('Média de Leis Citadas por Tipo de Lei e Matéria (OAB)')
plt.xlabel('Tipo de Lei')
plt.ylabel('Matéria')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
from collections import Counter

# 1. Converte a coluna Rule para dicionário (se ainda não estiver)
oab_exam_df['Rule_dict'] = oab_exam_df['Rule'].apply(
    lambda x: json.loads(x) if isinstance(x, str) else x
)

# 2. Extrai todos os valores do campo "numero" dentro de qualquer tipo de lei
all_laws = []
for rules in oab_exam_df['Rule_dict']:
    for law_list in rules.values():
        for item in law_list:
            numero = item.get('numero')
            if numero:
                all_laws.append(numero.strip())

# 3. Conta as leis mais frequentes
law_counts = Counter(all_laws)
top10 = law_counts.most_common(50)

# 4. Prepara para plotagem
labels, values = zip(*top10)

plt.figure(figsize=(10, 6))
plt.barh(labels, values, color='steelblue')
plt.xlabel('Número de Ocorrências')
plt.ylabel('Lei / Artigo')
plt.title('Top 10 Leis mais Citadas no Campo "Rule"')
plt.gca().invert_yaxis()  # coloca a mais citada no topo
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calcula a média de rule_count por matéria e ordena do menor para o maior
order = (
    oab_exam_df.groupby('materia')['rule_count']
    .mean()
    .sort_values()
    .index
)

plt.figure(figsize=(12, 6))
sns.boxplot(
    data=oab_exam_df,
    x='materia',
    y='rule_count',
    order=order,          # aplica a ordenação
    palette='Blues',
    showmeans=True,
    meanprops={"marker":"o", "markerfacecolor":"white", "markeredgecolor":"black"}
)

plt.xlabel('Matéria')
plt.ylabel('Número de Regras (rule_count)')
plt.title('Distribuição de rule_count por Matéria (ordenado pela média)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_13496\553100606.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calcula a média de fact_count por matéria e ordena do menor para o maior
order = (
    oab_exam_df.groupby('materia')['fact_count']
    .mean()
    .sort_values()
    .index
)

plt.figure(figsize=(12, 6))
sns.boxplot(
    data=oab_exam_df,
    x='materia',
    y='fact_count',
    order=order,
    palette='Greens',
    showmeans=True,
    meanprops={"marker":"o", "markerfacecolor":"white", "markeredgecolor":"black"}
)

plt.xlabel('Matéria')
plt.ylabel('Número de Fatos (fact_count)')
plt.title('Distribuição de fact_count por Matéria (ordenado pela média)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_13496\1146820083.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import nltk
import json
import re

# baixar stopwords (somente na primeira vez)
nltk.download("stopwords")

stopwords_pt = set(stopwords.words("portuguese"))

cols = ["Facts", "Issue", "Rule", "Application", "Conclusion"]

def extract_json_values(text):
    """Se for JSON válido, retorna apenas os valores. Senão, retorna o próprio texto."""
    try:
        obj = json.loads(text)
        # pega só os valores do JSON
        return " ".join(str(v) for v in obj.values())
    except:
        return text  # não era JSON, retorna o texto normal

for col in cols:
    # Tratamento especial para Rule
    if col == "Rule":
        processed = oab_exam_df[col].dropna().astype(str).apply(extract_json_values)
        text = " ".join(processed.values)
    else:
        text = " ".join(oab_exam_df[col].dropna().astype(str).values)

    wc = WordCloud(
        width=800,
        height=400,
        background_color="white",
        stopwords=stopwords_pt,
        collocations=True
    ).generate(text)

    plt.figure(figsize=(10,5))
    plt.title(f"WordCloud - {col}", fontsize=16)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\pedro\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
